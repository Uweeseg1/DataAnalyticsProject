# %%
import numpy as np
import pandas as pd 
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

# %%
# URIS CHECK git

# Assuming your DataFrame is named 'df' and the column is named 'date_column'

# Function to convert the date format
def convert_date(date_str):
    # Parse the date string into a datetime object
    date = datetime.strptime(date_str, '%b-%Y')
    # Format the datetime object into the desired format
    formatted_date = date.strftime('%d/%m/%Y')
    return formatted_date

# %%
Q1_19 = pd.read_csv("Q1_2019.csv",low_memory=False)
Q2_19 = pd.read_csv("Q2_2019.csv",low_memory=False)
Q3_19 = pd.read_csv("Q3_2019.csv",low_memory=False)
Q4_19 = pd.read_csv("Q4_2019.csv",low_memory=False)

# %%
Q1_18 = pd.read_csv("Q1_2018.csv",low_memory=False)
Q2_18 = pd.read_csv("Q2_2018.csv",low_memory=False)
Q3_18 = pd.read_csv("Q3_2018.csv",low_memory=False)
Q4_18 = pd.read_csv("Q4_2018.csv",low_memory=False)

# %%
Q1_18["Qrtr"] = 1
Q2_18["Qrtr"] = 2
Q3_18["Qrtr"] = 3
Q4_18["Qrtr"] = 4
Q1_19["Qrtr"] = 1
Q2_19["Qrtr"] = 2
Q3_19["Qrtr"] = 3
Q4_19["Qrtr"] = 4

# %%
# making 2 big Date Frames
all_year_19 = pd.concat([Q1_19,Q2_19,Q3_19,Q4_19])
all_year_18 = pd.concat([Q1_18,Q2_18,Q3_18,Q4_18])

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 500)
pd.options.display.max_rows
# Out:
# 500

# %%
# have a look
all_year_19.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  76143686        NaN       9000         9000           9000.0   36 months
# 1  76132182        NaN      24000        24000          24000.0   60 months
# 2  76143234        NaN       8000         8000           8000.0   36 months
# 3  75710736        NaN      12800        12800          12800.0   36 months
# 4  75858516        NaN       5000         5000           5000.0   36 months
#
#   int_rate  installment grade sub_grade              emp_title emp_length  \
# 0   15.31%       313.36     C        C5  Senior Case Assistant    9 years
# 1    6.49%       469.48     A        A2     Production Manager  10+ years
# 2   10.75%       260.97     B        B4                     Vp    5 years
# 3   11.99%       425.09     C        C1  LOGISTICS COORDINATOR    6 years
# 4   16.29%       176.51     D        D1           Investigator  10+ years
#
#   home_ownership  annual_inc verification_status   issue_d  loan_status  \
# 0           RENT     52000.0     Source Verified  Mar-2016   Fully Paid
# 1       MORTGAGE     92000.0        Not Verified  Mar-2016      Current
# 2           RENT     73000.0     Source Verified  Mar-2016   Fully Paid
# 3       MORTGAGE     53000.0            Verified  Mar-2016   Fully Paid
# 4       MORTGAGE    105000.0        Not Verified  Mar-2016  Charged Off
#
#   pymnt_plan                                                url desc  \
# 0          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 1          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 2          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 3          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 4          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
#
#               purpose                    title zip_code addr_state    dti  \
# 0  debt_consolidation       Debt consolidation    945xx         CA  18.86
# 1         credit_card  Credit card refinancing    370xx         TN  11.77
# 2  debt_consolidation       Debt consolidation    917xx         CA  10.85
# 3         credit_card  Credit card refinancing    330xx         FL  20.99
# 4  debt_consolidation       Debt consolidation    210xx         MD   9.07
#
#    delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 0            0         Nov-1999             665              669
# 1            0         Mar-2002             765              769
# 2            0         Jan-2005             735              739
# 3            0         Mar-2002             665              669
# 4            0         Jun-2005             710              714
#
#    inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  \
# 0             0.0                    24.0                     NaN         6
# 1             0.0                     NaN                     NaN        18
# 2             2.0                     NaN                     NaN         5
# 3             0.0                     NaN                    59.0         7
# 4             0.0                    24.0                     NaN        13
#
#    pub_rec  revol_bal revol_util  total_acc initial_list_status  out_prncp  \
# 0        0      11713      73.7%         13                   w       0.00
# 1        0      22950      21.6%         27                   w    9712.74
# 2        0       1824         8%          8                   w       0.00
# 3        1       8777      79.1%         16                   w       0.00
# 4        0       3791      67.7%         15                   w       0.00
#
#    out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0           0.00  10193.651743         10193.65          9000.00
# 1        9712.74  17822.930000         17822.93         14287.26
# 2           0.00   9421.150893          9421.15          8000.00
# 3           0.00  15289.811232         15289.81         12800.00
# 4           0.00   4418.320000          4418.32          2514.29
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0        1193.65                 0.0        0.00                   0.0000
# 1        3535.67                 0.0        0.00                   0.0000
# 2        1421.15                 0.0        0.00                   0.0000
# 3        2489.81                 0.0        0.00                   0.0000
# 4        1168.37                45.0      690.66                 124.3188
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0     Mar-2017          7064.14          NaN           Oct-2018
# 1     May-2019           469.48     Jul-2019           Jun-2019
# 2     Mar-2019           521.90          NaN           May-2019
# 3     Apr-2019           424.75          NaN           Mar-2019
# 4     Apr-2018           176.51          NaN           Feb-2019
#
#    last_fico_range_high  last_fico_range_low  collections_12_mths_ex_med  \
# 0                   699                  695                           0
# 1                   814                  810                           0
# 2                   694                  690                           0
# 3                   734                  730                           0
# 4                   579                  575                           0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                          NaN            1       Individual
# 1                          NaN            1       Individual
# 2                          NaN            1       Individual
# 3                          NaN            1       Individual
# 4                         24.0            1       Individual
#
#    annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0               NaN        NaN                       NaN               0
# 1               NaN        NaN                       NaN               0
# 2               NaN        NaN                       NaN               0
# 3               NaN        NaN                       NaN               0
# 4               NaN        NaN                       NaN               0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0             0        52953          2.0          1.0          1.0
# 1             0       131135          0.0          1.0          1.0
# 2             0        62125          1.0          2.0          0.0
# 3             0       221036          2.0          2.0          1.0
# 4             0       391073          1.0          9.0          2.0
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0          1.0                 4.0       41240.0      NaN          3.0
# 1          1.0                10.0        6038.0     79.0          1.0
# 2          1.0                13.0       60301.0     85.0          2.0
# 3          1.0                 9.0       23227.0     68.0          1.0
# 4          2.0                 1.0       98746.0    104.0          0.0
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0          3.0      3789.0      74.0             15900     0.0          1.0
# 1          4.0      9467.0      25.0            106400     0.0          0.0
# 2          3.0       854.0      47.0             22800     0.0          1.0
# 3          1.0      3381.0      71.0             11100     1.0          0.0
# 4          1.0      3624.0     102.0              5600     1.0          0.0
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0           2.0                     4         8826          4187.0     73.7
# 1           2.0                     5         7285         52435.0     21.2
# 2           2.0                     4        12425         20571.0      6.5
# 3           2.0                     3        31577           962.0     87.8
# 4           3.0                     3        32589          1809.0     67.7
#
#    chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                         0            0               125.0
# 1                         0            0               122.0
# 2                         0            0               134.0
# 3                         0            0               124.0
# 4                         0            0               128.0
#
#    mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                   196                      1               1         0
# 1                   168                     11              10         2
# 2                    84                      2               2         0
# 3                   168                      4               4         1
# 4                   129                     15               1         1
#
#    mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                   1.0                       NaN                    4.0
# 1                  20.0                       NaN                    9.0
# 2                   2.0                       NaN                    0.0
# 3                  43.0                       NaN                    7.0
# 4                  15.0                       NaN                    6.0
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                             NaN                      0               5
# 1                             NaN                      0               3
# 2                             NaN                      0               2
# 3                             NaN                      0               3
# 4                             NaN                      1               2
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0                5            5          9          3              5
# 1                9            8         12          4             16
# 2                3            2          3          4              3
# 3                4            3          4          7              4
# 4                2            3          3         11              3
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0             10                    5         6               0.0
# 1             21                    9        18               0.0
# 2              4                    3         5               0.0
# 3              8                    4         7               0.0
# 4              3                    2        13               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0             0                   0                   4            92.3
# 1             0                   0                   2           100.0
# 2             0                   0                   2           100.0
# 3             0                   0                   3           100.0
# 4             0                   0                   2            92.9
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0              80.0                     0          0            58425
# 1               0.0                     0          0           232603
# 2              50.0                     0          0            78840
# 3             100.0                     1          0           235600
# 4               0.0                     0          0           496358
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0              52953           15900                       42525
# 1              28988           66500                        7665
# 2              62125           22000                       56040
# 3              32004            7900                       34024
# 4             102537            5600                       94567
#
#    revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 0              NaN                     NaN                      NaN
# 1              NaN                     NaN                      NaN
# 2              NaN                     NaN                      NaN
# 3              NaN                     NaN                      NaN
# 4              NaN                     NaN                      NaN
#
#    sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0                       NaN                     NaN               NaN
# 1                       NaN                     NaN               NaN
# 2                       NaN                     NaN               NaN
# 3                       NaN                     NaN               NaN
# 4                       NaN                     NaN               NaN
#
#    sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2               NaN                 NaN                  NaN
# 3               NaN                 NaN                  NaN
# 4               NaN                 NaN                  NaN
#
#    sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#    sec_app_collections_12_mths_ex_med  sec_app_mths_since_last_major_derog  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#   hardship_flag hardship_type hardship_reason hardship_status  deferral_term  \
# 0             N           NaN             NaN             NaN            NaN
# 1             N           NaN             NaN             NaN            NaN
# 2             N           NaN             NaN             NaN            NaN
# 3             N           NaN             NaN             NaN            NaN
# 4             N           NaN             NaN             NaN            NaN
#
#    hardship_amount hardship_start_date hardship_end_date  \
# 0              NaN                 NaN               NaN
# 1              NaN                 NaN               NaN
# 2              NaN                 NaN               NaN
# 3              NaN                 NaN               NaN
# 4              NaN                 NaN               NaN
#
#   payment_plan_start_date  hardship_length  hardship_dpd hardship_loan_status  \
# 0                     NaN              NaN           NaN                  NaN
# 1                     NaN              NaN           NaN                  NaN
# 2                     NaN              NaN           NaN                  NaN
# 3                     NaN              NaN           NaN                  NaN
# 4                     NaN              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount debt_settlement_flag  \
# 0                           NaN                    N
# 1                           NaN                    N
# 2                           NaN                    N
# 3                           NaN                    N
# 4                           NaN                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term  Qrtr
# 0                NaN                    NaN              NaN     1
# 1                NaN                    NaN              NaN     1
# 2                NaN                    NaN              NaN     1
# 3                NaN                    NaN              NaN     1
# 4                NaN                    NaN              NaN     1

# %%
all_year_19.dtypes
# Out:
# id                                              int64
# member_id                                     float64
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                       object
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# pymnt_plan                                     object
# url                                            object
# desc                                           object
# purpose                                        object
# title                                          object
# zip_code                                       object
# addr_state                                     object
# dti                                           float64
# delinq_2yrs                                     int64
# earliest_cr_line                               object
# fico_range_low                                  int64
# fico_range_high                                 int64
# inq_last_6mths                                float64
# mths_since_last_delinq                        float64
# mths_since_last_record                        float64
# open_acc                                        int64
# pub_rec                                         int64
# revol_bal                                       int64
# revol_util                                     object
# total_acc                                       int64
# initial_list_status                            object
# out_prncp                                     float64
# out_prncp_inv                                 float64
# total_pymnt                                   float64
# total_pymnt_inv                               float64
# total_rec_prncp                               float64
# total_rec_int                                 float64
# total_rec_late_fee                            float64
# recoveries                                    float64
# collection_recovery_fee                       float64
# last_pymnt_d                                   object
# last_pymnt_amnt                               float64
# next_pymnt_d                                   object
# last_credit_pull_d                             object
# last_fico_range_high                            int64
# last_fico_range_low                             int64
# collections_12_mths_ex_med                      int64
# mths_since_last_major_derog                   float64
# policy_code                                     int64
# application_type                               object
# annual_inc_joint                              float64
# dti_joint                                     float64
# verification_status_joint                      object
# acc_now_delinq                                  int64
# tot_coll_amt                                    int64
# tot_cur_bal                                     int64
# open_acc_6m                                   float64
# open_act_il                                   float64
# open_il_12m                                   float64
# open_il_24m                                   float64
# mths_since_rcnt_il                            float64
# total_bal_il                                  float64
# il_util                                       float64
# open_rv_12m                                   float64
# open_rv_24m                                   float64
# max_bal_bc                                    float64
# all_util                                      float64
# total_rev_hi_lim                                int64
# inq_fi                                        float64
# total_cu_tl                                   float64
# inq_last_12m                                  float64
# acc_open_past_24mths                            int64
# avg_cur_bal                                     int64
# bc_open_to_buy                                float64
# bc_util                                       float64
# chargeoff_within_12_mths                        int64
# delinq_amnt                                     int64
# mo_sin_old_il_acct                            float64
# mo_sin_old_rev_tl_op                            int64
# mo_sin_rcnt_rev_tl_op                           int64
# mo_sin_rcnt_tl                                  int64
# mort_acc                                        int64
# mths_since_recent_bc                          float64
# mths_since_recent_bc_dlq                      float64
# mths_since_recent_inq                         float64
# mths_since_recent_revol_delinq                float64
# num_accts_ever_120_pd                           int64
# num_actv_bc_tl                                  int64
# num_actv_rev_tl                                 int64
# num_bc_sats                                     int64
# num_bc_tl                                       int64
# num_il_tl                                       int64
# num_op_rev_tl                                   int64
# num_rev_accts                                   int64
# num_rev_tl_bal_gt_0                             int64
# num_sats                                        int64
# num_tl_120dpd_2m                              float64
# num_tl_30dpd                                    int64
# num_tl_90g_dpd_24m                              int64
# num_tl_op_past_12m                              int64
# pct_tl_nvr_dlq                                float64
# percent_bc_gt_75                              float64
# pub_rec_bankruptcies                            int64
# tax_liens                                       int64
# tot_hi_cred_lim                                 int64
# total_bal_ex_mort                               int64
# total_bc_limit                                  int64
# total_il_high_credit_limit                      int64
# revol_bal_joint                               float64
# sec_app_fico_range_low                        float64
# sec_app_fico_range_high                       float64
# sec_app_earliest_cr_line                      float64
# sec_app_inq_last_6mths                        float64
# sec_app_mort_acc                              float64
# sec_app_open_acc                              float64
# sec_app_revol_util                            float64
# sec_app_open_act_il                           float64
# sec_app_num_rev_accts                         float64
# sec_app_chargeoff_within_12_mths              float64
# sec_app_collections_12_mths_ex_med            float64
# sec_app_mths_since_last_major_derog           float64
# hardship_flag                                  object
# hardship_type                                  object
# hardship_reason                                object
# hardship_status                                object
# deferral_term                                 float64
# hardship_amount                               float64
# hardship_start_date                            object
# hardship_end_date                              object
# payment_plan_start_date                        object
# hardship_length                               float64
# hardship_dpd                                  float64
# hardship_loan_status                           object
# orig_projected_additional_accrued_interest    float64
# hardship_payoff_balance_amount                float64
# hardship_last_payment_amount                  float64
# debt_settlement_flag                           object
# debt_settlement_flag_date                      object
# settlement_status                              object
# settlement_date                                object
# settlement_amount                             float64
# settlement_percentage                         float64
# settlement_term                               float64
# Qrtr                                            int64
# dtype: object

# %% [markdown]
# # Begining Initial Data Filtering

# %% [markdown]
# We have decided to focus our study on loans that are Mature with a term of 36 months as we are considering loans where we can study their entire lifetime, and not have biased data on loans which are still alive

# %%
ids_that_are_relevant = all_year_19[(all_year_19.term == " 36 months") & (all_year_19.loan_status.isin(["Default","Charged Off","Fully Paid"]))].id
(all_year_19.shape[0] - len(ids_that_are_relevant))/all_year_19.shape[0]
# Out:
# 0.3794114735720189

# %%
all_year_19 = all_year_19[all_year_19['id'].isin(ids_that_are_relevant)]
all_year_18 = all_year_18[all_year_18['id'].isin(ids_that_are_relevant)]

# %% [markdown]
# Bellow we are removing columns which exist in 2018 but not 2019

# %%
# Get a list of columns in each dataframe
cols_18 = set(all_year_18.columns)
cols_19 = set(all_year_19.columns)

# Find columns that are in one dataframe but not the other
missing_cols = [col for col in cols_18.symmetric_difference(cols_19)]

# Print the missing columns, if any
if missing_cols:
    print("Columns missing in one of the dataframes:")
    for col in missing_cols:
        if col in cols_18:
            print(f"Column '{col}' is missing in 'all_year_19'")
        else:
            print(f"Column '{col}' is missing in 'all_year_18'")
else:
    print("All columns match between the two dataframes.")
# Out:
# Columns missing in one of the dataframes:
# Column 'disbursement_method' is missing in 'all_year_19'

# %%
missing_cols
# Out:
# ['disbursement_method']

# %%
all_year_18 = all_year_18.drop(columns=missing_cols)

# %%
# in order to compare the loans across years we are will sort the ids and compare them
# Sort by id
all_year_18 = all_year_18.sort_values(by="id").reset_index(drop=True)
all_year_19 = all_year_19.sort_values(by="id").reset_index(drop=True)

# %% [markdown]
# ## Handiling N/A

# %%
all_year_19[all_year_19.settlement_term.notna() == True ]
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 36        666933        NaN      11200        11200          11200.0
# 67       1396078        NaN       6000         6000           6000.0
# 79       6906703        NaN      12000        12000          12000.0
# 94      11417840        NaN      10000        10000          10000.0
# 126     19197064        NaN       6000         6000           6000.0
# ...          ...        ...        ...          ...              ...
# 269435  96154358        NaN      13000        13000          13000.0
# 269480  96184171        NaN      12000        12000          12000.0
# 269546  96194593        NaN      20000        20000          20000.0
# 269547  96194601        NaN       8000         8000           8000.0
# 269558  96196413        NaN      35000        35000          34750.0
#
#               term int_rate  installment grade sub_grade  \
# 36       36 months   15.59%       391.50     C        C5
# 67       36 months   16.99%       213.89     D        D1
# 79       36 months    6.97%       370.37     A        A3
# 94       36 months   13.99%       341.73     C        C3
# 126      36 months    9.16%       191.25     B        B2
# ...            ...      ...          ...   ...       ...
# 269435   36 months   13.99%       444.25     C        C3
# 269480   36 months   18.99%       439.82     D        D3
# 269546   36 months   15.99%       703.05     C        C5
# 269547   36 months   16.99%       285.19     D        D1
# 269558   36 months   23.99%      1372.97     E        E2
#
#                       emp_title emp_length home_ownership  annual_inc  \
# 36                      Teacher  10+ years       MORTGAGE     42000.0
# 67      electronic engineer III  10+ years       MORTGAGE     75000.0
# 79            Diesel Technician  10+ years           RENT     60000.0
# 94                   salesman      2 years       MORTGAGE     88000.0
# 126                     foreman  10+ years       MORTGAGE    111000.0
# ...                         ...        ...            ...         ...
# 269435                  Manager  10+ years       MORTGAGE     68000.0
# 269480          Insurance Agent    9 years           RENT     52000.0
# 269546                   Driver    8 years            OWN     65000.0
# 269547                Receiver     3 years       MORTGAGE     30000.0
# 269558                      NaN        NaN       MORTGAGE    130000.0
#
#        verification_status   issue_d  loan_status pymnt_plan  \
# 36         Source Verified  Aug-2016  Charged Off          n
# 67         Source Verified  Jul-2016  Charged Off          n
# 79            Not Verified  Mar-2016  Charged Off          n
# 94         Source Verified  Sep-2016  Charged Off          n
# 126           Not Verified  Mar-2016  Charged Off          n
# ...                    ...       ...          ...        ...
# 269435        Not Verified  Dec-2016  Charged Off          n
# 269480        Not Verified  Dec-2016  Charged Off          n
# 269546        Not Verified  Dec-2016  Charged Off          n
# 269547            Verified  Dec-2016  Charged Off          n
# 269558            Verified  Dec-2016  Charged Off          n
#
#                                                       url desc  \
# 36      https://lendingclub.com/browse/loanDetail.acti...  NaN
# 67      https://lendingclub.com/browse/loanDetail.acti...  NaN
# 79      https://lendingclub.com/browse/loanDetail.acti...  NaN
# 94      https://lendingclub.com/browse/loanDetail.acti...  NaN
# 126     https://lendingclub.com/browse/loanDetail.acti...  NaN
# ...                                                   ...  ...
# 269435  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 269480  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 269546  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 269547  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 269558  https://lendingclub.com/browse/loanDetail.acti...  NaN
#
#                    purpose                    title zip_code addr_state  \
# 36      debt_consolidation       Debt consolidation    705xx         LA
# 67      debt_consolidation       Debt consolidation    856xx         AZ
# 79      debt_consolidation       Debt consolidation    907xx         CA
# 94        home_improvement         Home improvement    168xx         PA
# 126     debt_consolidation       Debt consolidation    117xx         NY
# ...                    ...                      ...      ...        ...
# 269435         credit_card  Credit card refinancing    488xx         MI
# 269480  debt_consolidation       Debt consolidation    225xx         VA
# 269546  debt_consolidation       Debt consolidation    605xx         IL
# 269547  debt_consolidation       Debt consolidation    145xx         NY
# 269558  debt_consolidation       Debt consolidation    206xx         MD
#
#           dti  delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 36      22.77            0         Oct-1991             680              684
# 67      34.42            0         Nov-2002             675              679
# 79      18.07            1         May-2000             700              704
# 94      11.61            0         Oct-1993             695              699
# 126     10.14            1         Feb-1993             665              669
# ...       ...          ...              ...             ...              ...
# 269435  32.67            0         May-1994             760              764
# 269480   3.53            0         Jun-1999             670              674
# 269546  28.08            0         Apr-2008             675              679
# 269547  22.60            1         Jun-2007             685              689
# 269558  29.31            0         Dec-1996             670              674
#
#         inq_last_6mths  mths_since_last_delinq  mths_since_last_record  \
# 36                 1.0                    28.0                   110.0
# 67                 0.0                     NaN                     NaN
# 79                 0.0                    12.0                     NaN
# 94                 1.0                    76.0                    17.0
# 126                1.0                     9.0                    68.0
# ...                ...                     ...                     ...
# 269435             1.0                     NaN                     NaN
# 269480             1.0                     NaN                    44.0
# 269546             0.0                     NaN                     NaN
# 269547             0.0                    14.0                     NaN
# 269558             0.0                    75.0                     NaN
#
#         open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 36             9        1      12159        77%         29
# 67            11        0      28954        82%         23
# 79            15        0      15209      39.4%         35
# 94             6        1     148676      68.6%         14
# 126           12        1       7188      20.6%         27
# ...          ...      ...        ...        ...        ...
# 269435        17        0      17192      27.5%         29
# 269480        10        1       4292      16.7%         43
# 269546         7        0      10134      63.3%         13
# 269547        16        0        693       9.4%         21
# 269558        21        0      34517      79.9%         30
#
#        initial_list_status  out_prncp  out_prncp_inv  total_pymnt  \
# 36                       f        0.0            0.0      5621.80
# 67                       w        0.0            0.0      4055.26
# 79                       w        0.0            0.0     10863.23
# 94                       w        0.0            0.0      8345.02
# 126                      w        0.0            0.0      3814.45
# ...                    ...        ...            ...          ...
# 269435                   f        0.0            0.0      7088.99
# 269480                   f        0.0            0.0      8214.99
# 269546                   w        0.0            0.0      9034.17
# 269547                   f        0.0            0.0      6907.86
# 269558                   f        0.0            0.0     24971.19
#
#         total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 36              5621.80          2888.73        1408.07                0.00
# 67              4055.26           801.55         470.46                0.00
# 79             10863.23          7719.26        1222.45               18.52
# 94              8345.02          6177.61        2016.14               51.27
# 126             3814.45          2795.09         644.36                0.00
# ...                 ...              ...            ...                 ...
# 269435          7088.99          1522.98         698.01                0.00
# 269480          8214.99          4192.66        2322.33                0.00
# 269546          9034.17          2829.07        1114.10                0.00
# 269547          6907.86          4873.24        2019.62               15.00
# 269558         24792.82         14415.04       10306.15                0.00
#
#         recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 36         1325.00                  238.500     Jul-2017           391.50
# 67         2783.25                  500.985     Jan-2017           213.89
# 79         1903.00                  342.540     Sep-2018            76.00
# 94          100.00                   18.000     Oct-2018           341.73
# 126         375.00                   67.500     Sep-2017           191.25
# ...            ...                      ...          ...              ...
# 269435     4868.00                  876.240     Jun-2017           469.25
# 269480     1700.00                  306.000     Mar-2018           439.82
# 269546     5091.00                  916.380     May-2017           703.05
# 269547        0.00                    0.000     May-2019            50.00
# 269558      250.00                   45.000     Jul-2018          1430.36
#
#        next_pymnt_d last_credit_pull_d  last_fico_range_high  \
# 36              NaN           Jun-2019                   609
# 67              NaN           Feb-2019                   534
# 79              NaN           Jun-2019                   544
# 94              NaN           Jun-2019                   594
# 126             NaN           Jun-2019                   599
# ...             ...                ...                   ...
# 269435          NaN           Aug-2018                   554
# 269480          NaN           Jun-2019                   519
# 269546          NaN           Jun-2019                   619
# 269547          NaN           Jun-2019                   594
# 269558          NaN           Jun-2019                   534
#
#         last_fico_range_low  collections_12_mths_ex_med  \
# 36                      605                           0
# 67                      530                           0
# 79                      540                           0
# 94                      590                           0
# 126                     595                           0
# ...                     ...                         ...
# 269435                  550                           0
# 269480                  515                           0
# 269546                  615                           0
# 269547                  590                           0
# 269558                  530                           0
#
#         mths_since_last_major_derog  policy_code application_type  \
# 36                             30.0            1       Individual
# 67                              NaN            1       Individual
# 79                              NaN            1       Individual
# 94                              NaN            1       Individual
# 126                             NaN            1       Individual
# ...                             ...          ...              ...
# 269435                          NaN            1       Individual
# 269480                          NaN            1       Individual
# 269546                          NaN            1       Individual
# 269547                          NaN            1        Joint App
# 269558                         75.0            1       Individual
#
#         annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 36                   NaN        NaN                       NaN               0
# 67                   NaN        NaN                       NaN               0
# 79                   NaN        NaN                       NaN               0
# 94                   NaN        NaN                       NaN               0
# 126                  NaN        NaN                       NaN               0
# ...                  ...        ...                       ...             ...
# 269435               NaN        NaN                       NaN               0
# 269480               NaN        NaN                       NaN               0
# 269546               NaN        NaN                       NaN               0
# 269547           60000.0      22.66              Not Verified               0
# 269558               NaN        NaN                       NaN               0
#
#         tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 36                 0        80610          0.0          1.0          0.0
# 67                 0       196057          0.0          3.0          1.0
# 79                 0        29975          0.0          2.0          1.0
# 94                 0       301144          0.0          1.0          1.0
# 126                0        20722          3.0          2.0          1.0
# ...              ...          ...          ...          ...          ...
# 269435             0        73533          1.0          3.0          1.0
# 269480             0         4292          2.0          0.0          0.0
# 269546           200        34023          0.0          3.0          0.0
# 269547          1111        35362          2.0         10.0          0.0
# 269558             0       226673          0.0          2.0          0.0
#
#         open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 36              0.0                49.0        5765.0     32.0          2.0
# 67              2.0                10.0       54916.0     86.0          0.0
# 79              2.0                12.0       14766.0     68.0          0.0
# 94              2.0                11.0       13542.0     88.0          0.0
# 126             2.0                 9.0       13534.0     68.0          3.0
# ...             ...                 ...           ...      ...          ...
# 269435          3.0                10.0       56341.0     83.0          2.0
# 269480          0.0                35.0           0.0      NaN          4.0
# 269546          1.0                13.0       23889.0     55.0          1.0
# 269547          1.0                20.0       34669.0    106.0          2.0
# 269558          0.0                29.0      192156.0     70.0          3.0
#
#         open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# 36              4.0      3949.0      53.0             15800     0.0
# 67              0.0     10935.0      84.0             35300     2.0
# 79              1.0      3616.0      50.0             38600     1.0
# 94              2.0      2030.0      82.0            155800     6.0
# 126             6.0      4711.0      38.0             34900     0.0
# ...             ...         ...       ...               ...     ...
# 269435          5.0      3950.0      56.0             62600     3.0
# 269480          8.0      3345.0      17.0             25700     0.0
# 269546          1.0      7260.0      57.0             16000     2.0
# 269547          2.0       689.0      88.0              7400     0.0
# 269558          6.0      7117.0      78.0             43200     0.0
#
#         total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 36              0.0           3.0                     4         8957
# 67              1.0           1.0                     4        17823
# 79              0.0           0.0                     3         2141
# 94              0.0           7.0                     4        50191
# 126             0.0           2.0                     8         1727
# ...             ...           ...                   ...          ...
# 269435          3.0           1.0                     8         4325
# 269480         10.0           2.0                     8          429
# 269546          1.0           1.0                     2         4860
# 269547          0.0           1.0                     3         2210
# 269558          0.0           1.0                     6        10794
#
#         bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 36               171.0     97.7                         0            0
# 67              2441.0     90.1                         0            0
# 79             19391.0     44.0                         0            0
# 94               153.0     95.5                         0            0
# 126            15022.0     26.7                         0            0
# ...                ...      ...                       ...          ...
# 269435         14810.0     27.4                         0            0
# 269480         15857.0     19.5                         0            0
# 269546          3044.0     74.4                         0            0
# 269547          2907.0     19.3                         0            0
# 269558          1839.0     92.4                         0            0
#
#         mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 36                   297.0                   104                      8
# 67                   122.0                    95                     26
# 79                    30.0                   190                     24
# 94                    94.0                   275                     13
# 126                  142.0                   277                      1
# ...                    ...                   ...                    ...
# 269435               138.0                   271                      1
# 269480               128.0                   210                      1
# 269546               104.0                    53                      7
# 269547               110.0                   114                      0
# 269558               240.0                   172                     11
#
#         mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 36                   8         1                  17.0
# 67                  10         6                  26.0
# 79                  12         0                  31.0
# 94                  11         1                  45.0
# 126                  1         4                   6.0
# ...                ...       ...                   ...
# 269435               1         0                  14.0
# 269480               1         0                   1.0
# 269546               7         1                  38.0
# 269547               0         0                   0.0
# 269558              11         0                  11.0
#
#         mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 36                          28.0                    0.0
# 67                           NaN                   10.0
# 79                          12.0                   22.0
# 94                           NaN                    0.0
# 126                          9.0                    6.0
# ...                          ...                    ...
# 269435                       NaN                    3.0
# 269480                       NaN                    1.0
# 269546                       NaN                    7.0
# 269547                      14.0                    9.0
# 269558                       NaN                   11.0
#
#         mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 36                                28.0                      1               2
# 67                                 NaN                      0               5
# 79                                12.0                      0               9
# 94                                 NaN                      1               2
# 126                                9.0                      0               3
# ...                                ...                    ...             ...
# 269435                             NaN                      0               3
# 269480                             NaN                      0               3
# 269546                             NaN                      0               3
# 269547                            14.0                      0               3
# 269558                             NaN                      1               9
#
#         num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 36                    7            2          8         14              7
# 67                    7            5          5          9              7
# 79                    9           11         20          3             13
# 94                    4            2          5          4              4
# 126                   4            5         12          5             10
# ...                 ...          ...        ...        ...            ...
# 269435                8            6          7          8             14
# 269480                4            7         19         10             10
# 269546                4            3          4          6              4
# 269547                3            3          3         15              6
# 269558               17            9         11          6             19
#
#         num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 36                 14                    7         9               0.0
# 67                  8                    7        11               0.0
# 79                 31                    9        15               0.0
# 94                  9                    4         6               0.0
# 126                18                    4        12               0.0
# ...               ...                  ...       ...               ...
# 269435             21                    8        17               0.0
# 269480             33                    4        10               0.0
# 269546              6                    4         7               0.0
# 269547              6                    3        16               0.0
# 269558             24                   17        21               0.0
#
#         num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 36                 0                   0                   2            72.4
# 67                 0                   0                   1           100.0
# 79                 0                   0                   1            94.3
# 94                 0                   0                   1            85.7
# 126                0                   0                   4            95.8
# ...              ...                 ...                 ...             ...
# 269435             0                   0                   3           100.0
# 269480             0                   0                   4           100.0
# 269546             0                   0                   1           100.0
# 269547             0                   0                   2            95.2
# 269558             0                   0                   3            93.3
#
#         percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 36                 100.0                     1          0           104243
# 67                  80.0                     0          0           218673
# 79                  10.0                     0          0            60310
# 94                 100.0                     0          1           379255
# 126                  0.0                     1          0            54900
# ...                  ...                   ...        ...              ...
# 269435              16.7                     0          0           130617
# 269480               0.0                     1          0            25700
# 269546              33.3                     0          0            59603
# 269547              33.3                     0          0            40236
# 269558             100.0                     0          0           220811
#
#         total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 36                  17924            7300                       18243
# 67                  83870           24700                       69003
# 79                  29975           34600                       21710
# 94                 162218            3400                       15455
# 126                 20722           20500                       20000
# ...                   ...             ...                         ...
# 269435              73533           20400                       68017
# 269480               4292           19700                           0
# 269546              34023           11900                       43603
# 269547              35362            3600                       32836
# 269558             226673           24300                      177611
#
#         revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 36                  NaN                     NaN                      NaN
# 67                  NaN                     NaN                      NaN
# 79                  NaN                     NaN                      NaN
# 94                  NaN                     NaN                      NaN
# 126                 NaN                     NaN                      NaN
# ...                 ...                     ...                      ...
# 269435              NaN                     NaN                      NaN
# 269480              NaN                     NaN                      NaN
# 269546              NaN                     NaN                      NaN
# 269547              NaN                     NaN                      NaN
# 269558              NaN                     NaN                      NaN
#
#         sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 36                           NaN                     NaN               NaN
# 67                           NaN                     NaN               NaN
# 79                           NaN                     NaN               NaN
# 94                           NaN                     NaN               NaN
# 126                          NaN                     NaN               NaN
# ...                          ...                     ...               ...
# 269435                       NaN                     NaN               NaN
# 269480                       NaN                     NaN               NaN
# 269546                       NaN                     NaN               NaN
# 269547                       NaN                     NaN               NaN
# 269558                       NaN                     NaN               NaN
#
#         sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 36                   NaN                 NaN                  NaN
# 67                   NaN                 NaN                  NaN
# 79                   NaN                 NaN                  NaN
# 94                   NaN                 NaN                  NaN
# 126                  NaN                 NaN                  NaN
# ...                  ...                 ...                  ...
# 269435               NaN                 NaN                  NaN
# 269480               NaN                 NaN                  NaN
# 269546               NaN                 NaN                  NaN
# 269547               NaN                 NaN                  NaN
# 269558               NaN                 NaN                  NaN
#
#         sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 36                        NaN                               NaN
# 67                        NaN                               NaN
# 79                        NaN                               NaN
# 94                        NaN                               NaN
# 126                       NaN                               NaN
# ...                       ...                               ...
# 269435                    NaN                               NaN
# 269480                    NaN                               NaN
# 269546                    NaN                               NaN
# 269547                    NaN                               NaN
# 269558                    NaN                               NaN
#
#         sec_app_collections_12_mths_ex_med  \
# 36                                     NaN
# 67                                     NaN
# 79                                     NaN
# 94                                     NaN
# 126                                    NaN
# ...                                    ...
# 269435                                 NaN
# 269480                                 NaN
# 269546                                 NaN
# 269547                                 NaN
# 269558                                 NaN
#
#         sec_app_mths_since_last_major_derog hardship_flag  \
# 36                                      NaN             N
# 67                                      NaN             N
# 79                                      NaN             N
# 94                                      NaN             N
# 126                                     NaN             N
# ...                                     ...           ...
# 269435                                  NaN             N
# 269480                                  NaN             N
# 269546                                  NaN             N
# 269547                                  NaN             N
# 269558                                  NaN             N
#
#                           hardship_type     hardship_reason hardship_status  \
# 36                                  NaN                 NaN             NaN
# 67                                  NaN                 NaN             NaN
# 79                                  NaN                 NaN             NaN
# 94      INTEREST ONLY-3 MONTHS DEFERRAL  INCOME_CURTAILMENT          BROKEN
# 126                                 NaN                 NaN             NaN
# ...                                 ...                 ...             ...
# 269435                              NaN                 NaN             NaN
# 269480                              NaN                 NaN             NaN
# 269546                              NaN                 NaN             NaN
# 269547                              NaN                 NaN             NaN
# 269558                              NaN                 NaN             NaN
#
#         deferral_term  hardship_amount hardship_start_date hardship_end_date  \
# 36                NaN              NaN                 NaN               NaN
# 67                NaN              NaN                 NaN               NaN
# 79                NaN              NaN                 NaN               NaN
# 94                3.0            44.57            Nov-2018          Dec-2018
# 126               NaN              NaN                 NaN               NaN
# ...               ...              ...                 ...               ...
# 269435            NaN              NaN                 NaN               NaN
# 269480            NaN              NaN                 NaN               NaN
# 269546            NaN              NaN                 NaN               NaN
# 269547            NaN              NaN                 NaN               NaN
# 269558            NaN              NaN                 NaN               NaN
#
#        payment_plan_start_date  hardship_length  hardship_dpd  \
# 36                         NaN              NaN           NaN
# 67                         NaN              NaN           NaN
# 79                         NaN              NaN           NaN
# 94                    Nov-2018              3.0          18.0
# 126                        NaN              NaN           NaN
# ...                        ...              ...           ...
# 269435                     NaN              NaN           NaN
# 269480                     NaN              NaN           NaN
# 269546                     NaN              NaN           NaN
# 269547                     NaN              NaN           NaN
# 269558                     NaN              NaN           NaN
#
#        hardship_loan_status  orig_projected_additional_accrued_interest  \
# 36                      NaN                                         NaN
# 67                      NaN                                         NaN
# 79                      NaN                                         NaN
# 94        Late (16-30 days)                                         NaN
# 126                     NaN                                         NaN
# ...                     ...                                         ...
# 269435                  NaN                                         NaN
# 269480                  NaN                                         NaN
# 269546                  NaN                                         NaN
# 269547                  NaN                                         NaN
# 269558                  NaN                                         NaN
#
#         hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 36                                 NaN                           NaN
# 67                                 NaN                           NaN
# 79                                 NaN                           NaN
# 94                             3912.15                         71.68
# 126                                NaN                           NaN
# ...                                ...                           ...
# 269435                             NaN                           NaN
# 269480                             NaN                           NaN
# 269546                             NaN                           NaN
# 269547                             NaN                           NaN
# 269558                             NaN                           NaN
#
#        debt_settlement_flag debt_settlement_flag_date settlement_status  \
# 36                        Y                  Sep-2018            ACTIVE
# 67                        Y                  Mar-2019          COMPLETE
# 79                        Y                  Jun-2019          COMPLETE
# 94                        Y                  Mar-2019            ACTIVE
# 126                       Y                  Apr-2018            ACTIVE
# ...                     ...                       ...               ...
# 269435                    Y                  Jul-2018          COMPLETE
# 269480                    Y                  Sep-2018            ACTIVE
# 269546                    Y                  Nov-2017            ACTIVE
# 269547                    Y                  Apr-2019            ACTIVE
# 269558                    Y                  Feb-2019            ACTIVE
#
#        settlement_date  settlement_amount  settlement_percentage  \
# 36            Aug-2018            3991.83                  45.00
# 67            Oct-2017            2783.23                  50.00
# 79            Aug-2018            1979.00                  44.99
# 94            Mar-2019            1829.00                  45.01
# 126           Mar-2018            1504.00                  45.00
# ...                ...                ...                    ...
# 269435        Feb-2018            4868.00                  40.00
# 269480        Sep-2018            4224.00                  50.01
# 269546        Nov-2017            8258.00                  45.00
# 269547        Apr-2019            1474.00                  45.01
# 269558        Jan-2019           10220.06                  45.00
#
#         settlement_term  Qrtr
# 36                 17.0     3
# 67                 18.0     3
# 79                 10.0     1
# 94                 24.0     3
# 126                24.0     1
# ...                 ...   ...
# 269435              1.0     4
# 269480             14.0     4
# 269546             24.0     4
# 269547             18.0     4
# 269558             18.0     4
#
# [8552 rows x 151 columns]

# %%
all_year_19.isna().sum() /  len(all_year_19)
# Out:
# id                                            0.000000
# member_id                                     1.000000
# loan_amnt                                     0.000000
# funded_amnt                                   0.000000
# funded_amnt_inv                               0.000000
# term                                          0.000000
# int_rate                                      0.000000
# installment                                   0.000000
# grade                                         0.000000
# sub_grade                                     0.000000
# emp_title                                     0.072436
# emp_length                                    0.071947
# home_ownership                                0.000000
# annual_inc                                    0.000000
# verification_status                           0.000000
# issue_d                                       0.000000
# loan_status                                   0.000000
# pymnt_plan                                    0.000000
# url                                           0.000000
# desc                                          0.999944
# purpose                                       0.000000
# title                                         0.054212
# zip_code                                      0.000000
# addr_state                                    0.000000
# dti                                           0.000130
# delinq_2yrs                                   0.000000
# earliest_cr_line                              0.000000
# fico_range_low                                0.000000
# fico_range_high                               0.000000
# inq_last_6mths                                0.000000
# mths_since_last_delinq                        0.471749
# mths_since_last_record                        0.803281
# open_acc                                      0.000000
# pub_rec                                       0.000000
# revol_bal                                     0.000000
# revol_util                                    0.000664
# total_acc                                     0.000000
# initial_list_status                           0.000000
# out_prncp                                     0.000000
# out_prncp_inv                                 0.000000
# total_pymnt                                   0.000000
# total_pymnt_inv                               0.000000
# total_rec_prncp                               0.000000
# total_rec_int                                 0.000000
# total_rec_late_fee                            0.000000
# recoveries                                    0.000000
# collection_recovery_fee                       0.000000
# last_pymnt_d                                  0.001506
# last_pymnt_amnt                               0.000000
# next_pymnt_d                                  0.999981
# last_credit_pull_d                            0.000030
# last_fico_range_high                          0.000000
# last_fico_range_low                           0.000000
# collections_12_mths_ex_med                    0.000000
# mths_since_last_major_derog                   0.706467
# policy_code                                   0.000000
# application_type                              0.000000
# annual_inc_joint                              0.984640
# dti_joint                                     0.984647
# verification_status_joint                     0.984640
# acc_now_delinq                                0.000000
# tot_coll_amt                                  0.000000
# tot_cur_bal                                   0.000000
# open_acc_6m                                   0.000163
# open_act_il                                   0.000163
# open_il_12m                                   0.000163
# open_il_24m                                   0.000163
# mths_since_rcnt_il                            0.030228
# total_bal_il                                  0.000163
# il_util                                       0.139324
# open_rv_12m                                   0.000163
# open_rv_24m                                   0.000163
# max_bal_bc                                    0.000163
# all_util                                      0.000223
# total_rev_hi_lim                              0.000000
# inq_fi                                        0.000163
# total_cu_tl                                   0.000163
# inq_last_12m                                  0.000163
# acc_open_past_24mths                          0.000000
# avg_cur_bal                                   0.000000
# bc_open_to_buy                                0.011514
# bc_util                                       0.012018
# chargeoff_within_12_mths                      0.000000
# delinq_amnt                                   0.000000
# mo_sin_old_il_acct                            0.030083
# mo_sin_old_rev_tl_op                          0.000000
# mo_sin_rcnt_rev_tl_op                         0.000000
# mo_sin_rcnt_tl                                0.000000
# mort_acc                                      0.000000
# mths_since_recent_bc                          0.010835
# mths_since_recent_bc_dlq                      0.743293
# mths_since_recent_inq                         0.103042
# mths_since_recent_revol_delinq                0.636082
# num_accts_ever_120_pd                         0.000000
# num_actv_bc_tl                                0.000000
# num_actv_rev_tl                               0.000000
# num_bc_sats                                   0.000000
# num_bc_tl                                     0.000000
# num_il_tl                                     0.000000
# num_op_rev_tl                                 0.000000
# num_rev_accts                                 0.000000
# num_rev_tl_bal_gt_0                           0.000000
# num_sats                                      0.000000
# num_tl_120dpd_2m                              0.045736
# num_tl_30dpd                                  0.000000
# num_tl_90g_dpd_24m                            0.000000
# num_tl_op_past_12m                            0.000000
# pct_tl_nvr_dlq                                0.000000
# percent_bc_gt_75                              0.011599
# pub_rec_bankruptcies                          0.000000
# tax_liens                                     0.000000
# tot_hi_cred_lim                               0.000000
# total_bal_ex_mort                             0.000000
# total_bc_limit                                0.000000
# total_il_high_credit_limit                    0.000000
# revol_bal_joint                               1.000000
# sec_app_fico_range_low                        1.000000
# sec_app_fico_range_high                       1.000000
# sec_app_earliest_cr_line                      1.000000
# sec_app_inq_last_6mths                        1.000000
# sec_app_mort_acc                              1.000000
# sec_app_open_acc                              1.000000
# sec_app_revol_util                            1.000000
# sec_app_open_act_il                           1.000000
# sec_app_num_rev_accts                         1.000000
# sec_app_chargeoff_within_12_mths              1.000000
# sec_app_collections_12_mths_ex_med            1.000000
# sec_app_mths_since_last_major_derog           1.000000
# hardship_flag                                 0.000000
# hardship_type                                 0.991958
# hardship_reason                               0.991958
# hardship_status                               0.991958
# deferral_term                                 0.991958
# hardship_amount                               0.991958
# hardship_start_date                           0.991958
# hardship_end_date                             0.991958
# payment_plan_start_date                       0.991958
# hardship_length                               0.991958
# hardship_dpd                                  0.991958
# hardship_loan_status                          0.991958
# orig_projected_additional_accrued_interest    0.994332
# hardship_payoff_balance_amount                0.991958
# hardship_last_payment_amount                  0.991958
# debt_settlement_flag                          0.000000
# debt_settlement_flag_date                     0.968278
# settlement_status                             0.968278
# settlement_date                               0.968278
# settlement_amount                             0.968278
# settlement_percentage                         0.968278
# settlement_term                               0.968278
# Qrtr                                          0.000000
# dtype: float64

# %% [markdown]
# After looking at the data and the percentage of nas in every specific column we decided to remove all data with more than 40% Na's

# %%
COLUMNS_REMOVED_BECAUSE_OF_NA = all_year_19.columns[all_year_19.isna().sum() >= len(all_year_19)*0.4]

# %%
DF_FILTERED_OUT_COLUMNS = all_year_19[COLUMNS_REMOVED_BECAUSE_OF_NA]

# %%
all_year_19 = all_year_19[all_year_19.columns].drop(columns=COLUMNS_REMOVED_BECAUSE_OF_NA)

# %% [markdown]
# What we are doing bellow is finding all columns with less than 40% na values in 2019 from all datasets

# %%
all_year_18 = all_year_18[all_year_19.columns]

# %% [markdown]
# # Here we are removing columns that are only unique values

# %%
all_year_19.columns[all_year_19.nunique() == 1]
# Out:
# Index(['term', 'pymnt_plan', 'policy_code', 'hardship_flag'], dtype='object')

# %%
UNIQUE_COLUMNS = all_year_19.columns[all_year_19.nunique() == 1]

# %%
for column in UNIQUE_COLUMNS:
    DF_FILTERED_OUT_COLUMNS[column] = all_year_19[column]

# %%
all_year_19 = all_year_19[all_year_19.columns].drop(columns=UNIQUE_COLUMNS)

# %%
all_year_18 = all_year_18[all_year_19.columns]

# %%
UNIQUE_COLUMNS
# Out:
# Index(['term', 'pymnt_plan', 'policy_code', 'hardship_flag'], dtype='object')

# %%
# Calculate the percentage of identical values for each column
identical_percentages = all_year_19.apply(lambda x: x.value_counts(normalize=True).max(), axis=0)

# Filter the columns that have identical values for over 95% of the rows
IDENTICAL_COLS = identical_percentages[identical_percentages > 0.95].index.tolist()

IDENTICAL_COLS
# Out:
# ['out_prncp',
#  'out_prncp_inv',
#  'collections_12_mths_ex_med',
#  'application_type',
#  'acc_now_delinq',
#  'chargeoff_within_12_mths',
#  'delinq_amnt',
#  'num_tl_120dpd_2m',
#  'num_tl_30dpd',
#  'tax_liens',
#  'debt_settlement_flag']

# %%
all_year_19 = all_year_19[all_year_19.columns].drop(columns=IDENTICAL_COLS)

# %%
all_year_18 = all_year_18[all_year_19.columns]

# %%
all_year_19
# Out:
#               id  loan_amnt  funded_amnt  funded_amnt_inv int_rate  \
# 0          55716       3500         3500           3500.0   24.99%
# 1          56121       8000         8000           8000.0    6.49%
# 2          65104       8800         8800           8800.0   18.99%
# 3         347674       6000         6000           6000.0   13.67%
# 4         363009      35000        35000          35000.0   13.67%
# ...          ...        ...          ...              ...      ...
# 269583  96389124      15000        15000          15000.0    5.32%
# 269584  96409250       8000         8000           8000.0    7.99%
# 269585  96419201      13000        13000          13000.0    5.32%
# 269586  96429334       6000         6000           6000.0    7.49%
# 269587  96453160      15000        15000          15000.0   19.99%
#
#         installment grade sub_grade                            emp_title  \
# 0            139.15     E        E4                         Receptionist
# 1            245.16     A        A2                         Maintenance
# 2            322.53     D        D4                           hr manager
# 3            204.11     C        C3                   Sublet cordinator
# 4           1190.62     C        C3                                  CIO
# ...             ...   ...       ...                                  ...
# 269583       451.73     A        A1                    Emergency manager
# 269584       250.66     A        A5                             Techniti
# 269585       391.50     A        A1                     flight attendant
# 269586       186.61     A        A4  Empty Multi-level Distribution Supv
# 269587       557.38     D        D4                   Systems Specialist
#
#        emp_length home_ownership  annual_inc verification_status   issue_d  \
# 0        < 1 year           RENT     30784.0        Not Verified  Aug-2016
# 1       10+ years       MORTGAGE     65000.0        Not Verified  Jan-2016
# 2         2 years           RENT     65000.0     Source Verified  May-2016
# 3         2 years           RENT     30000.0        Not Verified  Apr-2016
# 4         3 years           RENT    180000.0            Verified  Mar-2016
# ...           ...            ...         ...                 ...       ...
# 269583  10+ years       MORTGAGE     98000.0     Source Verified  Dec-2016
# 269584  10+ years       MORTGAGE     57000.0     Source Verified  Dec-2016
# 269585  10+ years       MORTGAGE    101800.0        Not Verified  Dec-2016
# 269586    5 years           RENT     60000.0            Verified  Dec-2016
# 269587   < 1 year           RENT     78200.0            Verified  Dec-2016
#
#         loan_status                                                url  \
# 0        Fully Paid  https://lendingclub.com/browse/loanDetail.acti...
# 1       Charged Off  https://lendingclub.com/browse/loanDetail.acti...
# 2       Charged Off  https://lendingclub.com/browse/loanDetail.acti...
# 3        Fully Paid  https://lendingclub.com/browse/loanDetail.acti...
# 4        Fully Paid  https://lendingclub.com/browse/loanDetail.acti...
# ...             ...                                                ...
# 269583   Fully Paid  https://lendingclub.com/browse/loanDetail.acti...
# 269584   Fully Paid  https://lendingclub.com/browse/loanDetail.acti...
# 269585  Charged Off  https://lendingclub.com/browse/loanDetail.acti...
# 269586   Fully Paid  https://lendingclub.com/browse/loanDetail.acti...
# 269587   Fully Paid  https://lendingclub.com/browse/loanDetail.acti...
#
#                    purpose                    title zip_code addr_state  \
# 0       debt_consolidation       Debt consolidation    984xx         WA
# 1         home_improvement         Home improvement    686xx         NE
# 2       debt_consolidation       Debt consolidation    049xx         ME
# 3                    other                    Other    925xx         CA
# 4       debt_consolidation       Debt consolidation    222xx         VA
# ...                    ...                      ...      ...        ...
# 269583         credit_card  Credit card refinancing    190xx         PA
# 269584         credit_card  Credit card refinancing    666xx         KS
# 269585         credit_card  Credit card refinancing    461xx         IN
# 269586      small_business                 Business    303xx         GA
# 269587  debt_consolidation       Debt consolidation    112xx         NY
#
#           dti  delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 0       16.96            0         Apr-2003             665              669
# 1       10.84            0         Mar-2002             705              709
# 2       18.24            0         Sep-2002             660              664
# 3       13.02            0         May-2006             710              714
# 4       16.31            0         Mar-2001             665              669
# ...       ...          ...              ...             ...              ...
# 269583   4.76            1         Feb-2003             705              709
# 269584  28.45            3         Oct-1996             680              684
# 269585  18.91            0         Jul-1997             720              724
# 269586  20.06            0         Mar-2003             705              709
# 269587  10.93            0         Oct-2003             675              679
#
#         inq_last_6mths  open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 0                  4.0        14        1       7849        74%         36
# 1                  0.0         5        1       3012      35.4%         11
# 2                  1.0        19        0      14741      81.9%         26
# 3                  0.0         9        0       4557        26%         12
# 4                  0.0         5        0      26143     100.5%         39
# ...                ...       ...      ...        ...        ...        ...
# 269583             0.0        15        0       8012      10.5%         31
# 269584             0.0         7        0       5938      36.7%         34
# 269585             0.0         8        3      21213      57.5%         21
# 269586             0.0         7        0      12442      39.6%         22
# 269587             0.0         9        0      13846      79.6%         26
#
#        initial_list_status   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0                        w   4737.256142          4737.26          3500.00
# 1                        w   5145.480000          5145.48          4477.11
# 2                        w   7123.750000          7123.75          5180.89
# 3                        w   7043.272508          7043.27          6000.00
# 4                        f  41853.125632         41853.13         35000.00
# ...                    ...           ...              ...              ...
# 269583                   w  15914.694801         15914.69         15000.00
# 269584                   w   8342.110922          8342.11          8000.00
# 269585                   w   5862.890000          5862.89          5166.44
# 269586                   w   6640.163454          6640.16          6000.00
# 269587                   f  19733.611970         19733.61         15000.00
#
#         total_rec_int  total_rec_late_fee  recoveries  \
# 0             1237.26            0.000000        0.00
# 1              668.37            0.000000        0.00
# 2             1435.14            0.000000      507.72
# 3             1043.27            0.000000        0.00
# 4             6853.13            0.000000        0.00
# ...               ...                 ...         ...
# 269583         914.69            0.000000        0.00
# 269584         342.11            0.000000        0.00
# 269585         696.45            0.000000        0.00
# 269586         640.16            0.000000        0.00
# 269587        4677.87           55.740001        0.00
#
#         collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0                        0.0000     Jun-2018          1752.66
# 1                        0.0000     Nov-2017           245.16
# 2                       91.3896     Aug-2017           322.53
# 3                        0.0000     Dec-2017          3198.79
# 4                        0.0000     Mar-2018         14599.97
# ...                         ...          ...              ...
# 269583                   0.0000     Jun-2018          8698.09
# 269584                   0.0000     Aug-2017          6847.03
# 269585                   0.0000     Apr-2018           391.50
# 269586                   0.0000     Feb-2019          2167.76
# 269587                   0.0000     Apr-2019             0.01
#
#        last_credit_pull_d  last_fico_range_high  last_fico_range_low  \
# 0                Jun-2019                   649                  645
# 1                Jun-2019                   524                  520
# 2                Jan-2018                   504                  500
# 3                Mar-2019                   759                  755
# 4                Apr-2018                   759                  755
# ...                   ...                   ...                  ...
# 269583           Jul-2018                   734                  730
# 269584           Jun-2019                   689                  685
# 269585           Apr-2018                   724                  720
# 269586           Feb-2019                   799                  795
# 269587           Apr-2019                   644                  640
#
#         tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0                  0         8351          0.0          1.0          0.0
# 1                  0        74131          0.0          2.0          0.0
# 2                  0       173057          2.0         12.0          2.0
# 3                  0         8950          2.0          0.0          0.0
# 4                  0       222371          0.0          3.0          1.0
# ...              ...          ...          ...          ...          ...
# 269583           434       175233          2.0          1.0          0.0
# 269584             0       146207          0.0          3.0          0.0
# 269585             0       168092          0.0          2.0          0.0
# 269586             0        45718          0.0          2.0          1.0
# 269587             0       129058          0.0          5.0          0.0
#
#         open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0               0.0                50.0         502.0      8.0          4.0
# 1               1.0                15.0       17290.0     73.0          0.0
# 2               6.0                 6.0      158316.0    115.0          3.0
# 3               1.0                13.0        4393.0     92.0          4.0
# 4               1.0                 8.0      196228.0     92.0          0.0
# ...             ...                 ...           ...      ...          ...
# 269583          1.0                19.0        1680.0     14.0          3.0
# 269584          1.0                19.0       65964.0     30.0          1.0
# 269585          2.0                14.0       20845.0     40.0          2.0
# 269586          1.0                 8.0       33276.0     84.0          0.0
# 269587          2.0                17.0      115212.0    107.0          1.0
#
#         open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# 0              13.0      1158.0      74.0             10650     2.0
# 1               1.0      1569.0      63.0              8500     2.0
# 2               3.0      4878.0     110.0             18000     2.0
# 3               8.0      1502.0      40.0             17500     0.0
# 4               0.0         0.0      95.0             26000     0.0
# ...             ...         ...       ...               ...     ...
# 269583          6.0      3151.0      11.0             76300     0.0
# 269584          1.0      2480.0      32.0             16200     0.0
# 269585          3.0      2482.0      47.0             36900     1.0
# 269586          5.0      4910.0      64.0             31400     3.0
# 269587          1.0      6084.0      98.0             17400     0.0
#
#         total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 0               4.0           6.0                    13          596
# 1               0.0           1.0                     3        14826
# 2               2.0           4.0                     9         9108
# 3               0.0           0.0                     9          994
# 4               1.0           0.0                     1        55593
# ...             ...           ...                   ...          ...
# 269583          1.0           1.0                     7        12517
# 269584          2.0           1.0                     2        20887
# 269585          2.0           2.0                     5        21012
# 269586          0.0           4.0                     6         6531
# 269587          3.0           0.0                     3        14340
#
#         bc_open_to_buy  bc_util  mo_sin_old_il_acct  mo_sin_old_rev_tl_op  \
# 0                907.0     79.0               160.0                   127
# 1               5488.0     35.4               166.0                    35
# 2               2654.0     81.8               163.0                    48
# 3               8624.0     33.7               119.0                    63
# 4                  NaN      NaN               163.0                   180
# ...                ...      ...                 ...                   ...
# 269583         32812.0     12.5               137.0                   166
# 269584            20.0     99.2               242.0                   227
# 269585           718.0     77.6               142.0                   233
# 269586         14182.0     40.7               165.0                   138
# 269587            54.0     99.6               120.0                   158
#
#         mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 0                           7               7         0                   7.0
# 1                          16              12         3                  16.0
# 2                           6               6         0                   6.0
# 3                           5               5         0                   5.0
# 4                          55               8         0                   NaN
# ...                       ...             ...       ...                   ...
# 269583                      4               4         3                   4.0
# 269584                      9               9         3                   9.0
# 269585                     11              11         3                  11.0
# 269586                     15               8         1                  94.0
# 269587                     10              10         0                  10.0
#
#         mths_since_recent_inq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                         2.0                      1               7
# 1                         3.0                      0               2
# 2                         0.0                      1               4
# 3                        23.0                      0               5
# 4                         NaN                      1               0
# ...                       ...                    ...             ...
# 269583                   12.0                      0               2
# 269584                    9.0                      2               1
# 269585                   11.0                      0               1
# 269586                    9.0                      2               3
# 269587                   17.0                      0               3
#
#         num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0                    13           14         17         11             13
# 1                     2            2          2          5              2
# 2                     6            5          5         19              7
# 3                     6            6          6          2              8
# 4                     1            0          4         30              2
# ...                 ...          ...        ...        ...            ...
# 269583                5            5          9          4             12
# 269584                3            1         10         16              3
# 269585                4            1          4          7              5
# 269586                4            3          7          8              5
# 269587                3            3          4         13              4
#
#         num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_90g_dpd_24m  \
# 0                  25                   13        14                   0
# 1                   3                    2         5                   0
# 2                   7                    6        19                   0
# 3                  10                    6         9                   0
# 4                   9                    1         5                   0
# ...               ...                  ...       ...                 ...
# 269583             24                    5        15                   0
# 269584             15                    3         7                   1
# 269585             11                    4         8                   0
# 269586             13                    4         7                   0
# 269587             12                    3         9                   0
#
#         num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# 0                        4            69.0              85.7
# 1                        1           100.0               0.0
# 2                        5           100.0              60.0
# 3                        4           100.0              16.7
# 4                        1           100.0               NaN
# ...                    ...             ...               ...
# 269583                   3            93.5               0.0
# 269584                   1            76.5             100.0
# 269585                   2           100.0             100.0
# 269586                   1            90.9              33.3
# 269587                   1           100.0             100.0
#
#         pub_rec_bankruptcies  tot_hi_cred_lim  total_bal_ex_mort  \
# 0                          1            16579               8351
# 1                          1            87102              20302
# 2                          0           145285             173057
# 3                          0            22300               8950
# 4                          0           233798             222371
# ...                      ...              ...                ...
# 269583                     0           269003               9692
# 269584                     0           185355              71902
# 269585                     0           244965              42058
# 269586                     0            70949              45718
# 269587                     0           120048             129058
#
#         total_bc_limit  total_il_high_credit_limit  Qrtr
# 0                 6350                        5929     3
# 1                 8500                       23822     1
# 2                14600                      127285     2
# 3                13000                        4800     2
# 4                    0                      207798     1
# ...                ...                         ...   ...
# 269583           37500                       12489     4
# 269584            2500                       88422     4
# 269585            3200                       52184     4
# 269586           23900                       39549     4
# 269587           13900                      102648     4
#
# [269588 rows x 92 columns]

# %% [markdown]
# ## Columns to remove becasue of data leakage

# %%
DATA_LEAKAGE_COLUMNS = []
# Columns to drop by number of N/A's

DATA_LEAKAGE_COLUMNS += (list(all_year_19.columns[all_year_18.isna().sum()!=all_year_19.isna().sum()]))

# %%
DATA_LEAKAGE_COLUMNS
# Out:
# ['last_credit_pull_d']

# %%
percentage_change = ((np.sum(all_year_18 != all_year_19) - np.sum(all_year_19.isna())) / all_year_19.shape[0])

# %%
percentage_change[(percentage_change >= 0.02 )]
# Out:
# loan_status                0.506217
# total_pymnt                0.534341
# total_pymnt_inv            0.534126
# total_rec_prncp            0.480941
# total_rec_int              0.482748
# total_rec_late_fee         0.024938
# recoveries                 0.075348
# collection_recovery_fee    0.075348
# last_pymnt_d               0.474194
# last_pymnt_amnt            0.451118
# last_credit_pull_d         0.811983
# last_fico_range_high       0.753231
# last_fico_range_low        0.753231
# dtype: float64

# %%
percentage_change[(percentage_change <= .02 ) & (percentage_change!=0)]
# Out:
# int_rate               0.000104
# installment            0.000108
# verification_status    0.017430
# dtype: float64

# %%
columns_to_keep_for_targetting = ['loan_status','total_pymnt','recoveries', 'last_pymnt_d','payment_lifetime','issue_d']
columns_to_keep_with_low_leakage_rate = ['int_rate','installment','verification_status']

# %%
percentage_change = percentage_change[percentage_change != 0]

# %%
percentage_change_to_drop = percentage_change.loc[(~percentage_change.index.isin(columns_to_keep_for_targetting)) & (~percentage_change.index.isin(columns_to_keep_with_low_leakage_rate))]

# %%
percentage_change_to_drop.index
# Out:
# Index(['total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'collection_recovery_fee', 'last_pymnt_amnt',
#        'last_credit_pull_d', 'last_fico_range_high', 'last_fico_range_low'],
#       dtype='object')

# %%
DATA_LEAKAGE_COLUMNS += (list(percentage_change_to_drop.index))

# %%
DATA_LEAKAGE_COLUMNS
# Out:
# ['last_credit_pull_d',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'collection_recovery_fee',
#  'last_pymnt_amnt',
#  'last_credit_pull_d',
#  'last_fico_range_high',
#  'last_fico_range_low']

# %%
for column in DATA_LEAKAGE_COLUMNS:
    DF_FILTERED_OUT_COLUMNS[column] = all_year_19[column]

# %%
all_year_19 = all_year_19[all_year_19.columns].drop(columns=DATA_LEAKAGE_COLUMNS)

# %%
### check::::::::::::

# %%
# for col_name in columns_to_keep_for_targetting:
#     #if col_name == 'last_pymnt_d':
#     #    continue
#     all_year_19.rename(columns={col_name: f'target_{col_name}' }, inplace=True)

# %%
columns_to_keep_for_targetting
# Out:
# ['loan_status',
#  'total_pymnt',
#  'recoveries',
#  'last_pymnt_d',
#  'payment_lifetime',
#  'issue_d']

# %% [markdown]
# # Data Leakage Removal- instances from
# ## columns_to_keep_with_low_leakage_rate

# %%
columns_to_keep_with_low_leakage_rate
# Out:
# ['int_rate', 'installment', 'verification_status']

# %%
number_of_instances_leaked = ((np.sum(all_year_18['int_rate'] != all_year_19['int_rate'])) )
print(f"only {number_of_instances_leaked} of leaked instances for int_rate")
# Out:
# only 28 of leaked instances for int_rate

# %%
leaked_instances = ((all_year_18[['int_rate']] == all_year_19[['int_rate']])).int_rate
sum(~leaked_instances)
all_year_19 = all_year_19.loc[leaked_instances, :]
all_year_18 = all_year_18.loc[leaked_instances, :]

# %%
leaked_instances = ((all_year_18[['installment']] == all_year_19[['installment']])).installment
sum(~leaked_instances)
all_year_19 = all_year_19.loc[leaked_instances, :]
all_year_18 = all_year_18.loc[leaked_instances, :]

# %%
all_year_19.shape
# Out:
# (269558, 83)

# %% [markdown]
# ## In the Case of verification_status we will take the 2018 value

# %%
leaked_instances = ((all_year_18[['verification_status']] == all_year_19[['verification_status']])).verification_status

# %%
sum(~leaked_instances)
# Out:
# 4699

# %%
all_year_19['verification_status'] = all_year_18['verification_status']

# %% [markdown]
# # <font color=blue> Above we have completed our initial filtration and now we are moving on to specific column EDA

# %% [markdown]
# # Creating Columns to calculate our target interest rate

# %%
# Here we are casting column to string
all_year_19['last_pymnt_d'] = all_year_19['last_pymnt_d'].astype(str)
all_year_19['issue_d'] = all_year_19['issue_d'].astype(str)
all_year_18['issue_d'] = all_year_18['issue_d'].astype(str)



'''
### replacing NA to 1.1.2010- why??

'''

all_year_19['last_pymnt_d'] = all_year_19['last_pymnt_d'].replace('nan', 'Jan-2010')


# Apply the conversion function to the column
all_year_19['last_pymnt_d'] = all_year_19['last_pymnt_d'].apply(convert_date)
all_year_19['issue_d'] = all_year_19['issue_d'].apply(convert_date)


all_year_19['last_pymnt_d'] = pd.to_datetime(all_year_19['last_pymnt_d'], format='%d/%m/%Y')
all_year_19['issue_d'] = pd.to_datetime(all_year_19['issue_d'], format='%d/%m/%Y')

all_year_19['loan_lifetime_in_months'] = ((all_year_19.last_pymnt_d - all_year_19.issue_d)/np.timedelta64(1, 'M'))
all_year_19['loan_lifetime_in_months'] = all_year_19['loan_lifetime_in_months'].astype(float)

# %%
# Giving a value of 1 month for loans with not a singe payment.
all_year_19['loan_lifetime_in_months'] = all_year_19['loan_lifetime_in_months'].clip(lower=1)

# %%
all_year_19['loan_lifetime_in_months'].describe()
# Out:
# count    269558.000000
# mean         20.987506
# std          11.042900
# min           1.000000
# 25%          11.992033
# 50%          20.961416
# 75%          31.015011
# max          40.970040
# Name: loan_lifetime_in_months, dtype: float64

# %% [markdown]
# # Creating columns to calculate the Interest return rate:

# %%
all_year_19["estimated_monthly_paymnent"] = all_year_19["total_pymnt"] / all_year_19["loan_lifetime_in_months"]

# %%
all_year_19["estimated_monthly_paymnent"].describe()
# Out:
# count    269558.000000
# mean       1127.352490
# std        2373.385822
# min           0.000000
# 25%         312.085892
# 50%         561.719399
# 75%        1052.075764
# max       41058.410000
# Name: estimated_monthly_paymnent, dtype: float64

# %%
m = np.array(all_year_19["loan_lifetime_in_months"]) # month from start to finish
t = 36 # only 36 months terms
p = np.array(all_year_19.total_pymnt) # total return
f = np.array(all_year_19.funded_amnt) # total invesment
i = (0.02+1)**(1/12)-1 # i = alternative reinvesment monthly rate 

# realised = (1/f) * ( ( (p/m)( (1-(1+i)*m) / (1-(1+i)) ) ) * (1+i)*(t-m) - f )

# %%
all_year_19['realised_return'] = (((1/f) * ( ( (p/m)*( (1-(1+i)**m) / (1-(1+i)) ) ) * (1+i)**(t-m) - f ))+1)**(12/t)-1

# %%
all_year_19['realised_return'].describe()
# Out:
# count    269558.000000
# mean          0.014439
# std           0.111051
# min          -1.000000
# 25%           0.032721
# 50%           0.048989
# 75%           0.065243
# max           0.319880
# Name: realised_return, dtype: float64

# %% [markdown]
# # Deep EDA - column specific
# Here we are looking at ways to replace NA's. based on number and distribution relative to target varriable

# %%
IRRELEVANT_COLUMNS = ['funded_amnt_inv','url','zip_code']
TO_DUMIFY = []
POTENTIAL_DATA_LEAKAG = []

# %%
all_year_19 = all_year_19[all_year_19.columns].drop(columns=IRRELEVANT_COLUMNS)

# %%
# before replacing na's we need to see they are not an indication to the target varriable
# we calculated the mean of realized return for the NA's in each column with NA's.
for i in all_year_19.columns : 
    n = all_year_19[i].isna().sum() 
    if n > 0 :
        realised_return = all_year_19[all_year_19[i].isna()]["realised_return"].mean()
        print(i,realised_return,n)
# Out:
# emp_title -0.003523550321398755 19527
# emp_length -0.0034668807427112565 19395
# title 0.010287832069108476 14613
# dti 0.016770655965160263 35
# revol_util 0.018919880551783036 179
# open_acc_6m 0.012470705519267787 44
# open_act_il 0.012470705519267787 44
# open_il_12m 0.012470705519267787 44
# open_il_24m 0.012470705519267787 44
# mths_since_rcnt_il 0.014684840699371211 8148
# total_bal_il 0.012470705519267787 44
# il_util 0.017743895132574457 37558
# open_rv_12m 0.012470705519267787 44
# open_rv_24m 0.012470705519267787 44
# max_bal_bc 0.012470705519267787 44
# all_util 0.018340745305163875 60
# inq_fi 0.012470705519267787 44
# total_cu_tl 0.012470705519267787 44
# inq_last_12m 0.012470705519267787 44
# bc_open_to_buy 0.014555448572163121 3103
# bc_util 0.014125245844969735 3239
# mo_sin_old_il_acct 0.014655466175076052 8109
# mths_since_recent_bc 0.01552031123920401 2920
# mths_since_recent_inq 0.024332532573211437 27777
# percent_bc_gt_75 0.014724079726894507 3126

# %%
na_rate = (all_year_19.isna().sum() /  len(all_year_19))

# %%
na_rate_ge0 = na_rate[(na_rate > 0)]

# %%
len(na_rate_ge0)
# Out:
# 25

# %%
all_year_19[all_year_19['emp_length'].isna()]['realised_return'].mean()
# Out:
# -0.0034668807427112565

# %%
all_year_19[all_year_19['emp_length'] == '< 1 year']['realised_return'].mean()
# Out:
# 0.012863025309224027

# %% [markdown]
# ### We see that there is a relashionship between 'emp_length' and the realized return and we assume that a missing value of length reffers to unemployment so we set the NA's to '0'.

# %%
all_year_19['emp_length'] = all_year_19['emp_length'].fillna(0)

# %%
all_year_19['emp_length'] = all_year_19['emp_length'].replace({'< 1 year': 0.5, '10+ years': 10, '2 years': 2,\
        '3 years': 3, '4 years': 4, '7 years': 7, '6 years': 6, '8 years': 8, '5 years': 5, '9 years': 9, \
        '1 year': 1})

# %%
all_year_19['emp_length'].unique()
# Out:
# array([ 0.5, 10. ,  2. ,  3. ,  4. ,  0. ,  7. ,  6. ,  8. ,  5. ,  9. ,
#         1. ])

# %%
distribution_dictionary = {}
for column in na_rate_ge0.index:
#     print(column)
    distribution = pd.DataFrame(columns=["Value", "Count", "Return on Investment Average", "Percentage"])

    unique_values = all_year_19[column].value_counts()
    num_unique_values = len(unique_values)

    for value in unique_values.index[:30]:
        distribution.loc[len(distribution)] = {
            "Value": value,
            "Count": unique_values[value],
            "Return on Investment Average": all_year_19[all_year_19[column] == value]['realised_return'].mean(),
            "Percentage": (unique_values[value] / all_year_19.shape[0]) * 100
        }

    distribution.loc[len(distribution)] = {
            "Value": 'na',
            "Count": all_year_19[column].isna().sum(),
            "Return on Investment Average": all_year_19[all_year_19[column].isna()]['realised_return'].mean(),
            "Percentage": (all_year_19[column].isna().sum() / all_year_19.shape[0]) * 100
        }
    distribution_dictionary[column] = distribution

# %%
# def fill_nas_with(df, column_name, replace_with):
#     df[column_name].fillna(replace_with, inplace=True)
#     return df

# %%
distribution_dictionary['title']
# Out:
#                         Value   Count  Return on Investment Average  \
# 0          Debt consolidation  140566                      0.013890
# 1     Credit card refinancing   54418                      0.019043
# 2                       Other   19109                      0.013896
# 3            Home improvement   18606                      0.015077
# 4              Major purchase    6585                      0.012618
# 5            Medical expenses    3523                      0.004278
# 6               Car financing    3201                      0.020973
# 7                    Business    2918                     -0.001603
# 8                    Vacation    2310                      0.013280
# 9       Moving and relocation    2271                      0.005184
# 10                Home buying    1235                      0.003615
# 11                 Green loan     202                     -0.002714
# 12  Credit Card Consolidation       1                      0.076920
# 13                         na   14613                      0.010288
#
#     Percentage
# 0    52.146848
# 1    20.187863
# 2     7.089012
# 3     6.902411
# 4     2.442888
# 5     1.306954
# 6     1.187500
# 7     1.082513
# 8     0.856958
# 9     0.842490
# 10    0.458157
# 11    0.074937
# 12    0.000371
# 13    5.421097

# %% [markdown]
# ###  #Column 'title': We replaced the NA with 'Unkown'

# %%
all_year_19['title'] = all_year_19['title'].fillna('Unknown')

# %%
all_year_19['title'].unique()
# Out:
# array(['Debt consolidation', 'Home improvement', 'Other',
#        'Major purchase', 'Unknown', 'Green loan', 'Vacation',
#        'Credit card refinancing', 'Car financing', 'Business',
#        'Credit Card Consolidation', 'Moving and relocation',
#        'Medical expenses', 'Home buying'], dtype=object)

# %%
sns.set(style="whitegrid")
ax = sns.distplot(all_year_19['dti'], kde=False, hist_kws={'edgecolor': 'black'})
ax.axvline(all_year_19['dti'].mean(), color='red', linestyle='--', label='Mean')
ax.axvline(all_year_19['dti'].median(), color='green', linestyle='--', label='Median')
ax.set_xlabel('dti')
ax.set_ylabel('Frequency')
ax.set_title('Histogram of dti')
ax.set_xlim(0, 150) 
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# /Users/maishamos/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### We are replacing NA's in 'dti' with the median.

# %%
all_year_19['dti'].mean(), all_year_19['dti'].median()
dti_med = all_year_19['dti'].median()
# Out:
# (18.57618158747094, 17.85)

# %%
all_year_19['dti'] = all_year_19['dti'].fillna(dti_med)

# %%
# remove the percentage sign from the 'revol_util' column and convert it to floats
all_year_19['revol_util'] = all_year_19['revol_util'].str.rstrip('%').astype('float') / 100

# %%
plt.hist(all_year_19['revol_util'], bins=20)
plt.xlabel('revol_util')
plt.ylabel('Frequency')
ax.axvline(all_year_19['revol_util'].mean(), color='red', linestyle='--', label='Mean')
ax.axvline(all_year_19['revol_util'].median(), color='green', linestyle='--', label='Median')
plt.title('Distribution of revol_util')
plt.show()

# %%
revol_util_med = all_year_19['revol_util'].median()

# %%
all_year_19['revol_util'] = all_year_19['revol_util'].fillna(revol_util_med)

# %%
# percent_bc_gt_75 

sns.displot(all_year_19['percent_bc_gt_75'])

print(all_year_19.realised_return[all_year_19.percent_bc_gt_75.isna()].mean(),all_year_19.percent_bc_gt_75.isna().sum())

bins = np.arange(0, 110, 10)

all_year_19.groupby(pd.cut(all_year_19['percent_bc_gt_75'], bins)).mean()["realised_return"]


# as its 1% with similer number of loans and mean realised rate
# we can use the closest bin of 30-40 
# assing 100 istead of nas (1%)

all_year_19.percent_bc_gt_75.fillna(value=100)
# Out:
# 0.014724079726894507 3126
# 0          85.7
# 1           0.0
# 2          60.0
# 3          16.7
# 4         100.0
#           ...
# 269583      0.0
# 269584    100.0
# 269585    100.0
# 269586     33.3
# 269587    100.0
# Name: percent_bc_gt_75, Length: 269558, dtype: float64

# %%
# open_acc_6m - look into 
# not leakege - nor resemble
print((1-(all_year_19.open_acc_6m == all_year_18.open_acc_6m).sum()/len(all_year_19))*100,"% leakege")

# high count for 0.0
all_year_19.open_acc_6m.value_counts()

# lets check rlsd rtrn 
print(all_year_19.realised_return[all_year_19["open_acc_6m"].isna()].mean())
all_year_19.groupby("open_acc_6m").mean()["realised_return"]

# assing 1 - closer mean rate and high count (only 44 na's)
all_year_19.fillna(value=1)
# Out:
# 0.016323017680797136 % leakege
# 0.012470705519267787
#               id  loan_amnt  funded_amnt int_rate  installment grade  \
# 0          55716       3500         3500   24.99%       139.15     E
# 1          56121       8000         8000    6.49%       245.16     A
# 2          65104       8800         8800   18.99%       322.53     D
# 3         347674       6000         6000   13.67%       204.11     C
# 4         363009      35000        35000   13.67%      1190.62     C
# ...          ...        ...          ...      ...          ...   ...
# 269583  96389124      15000        15000    5.32%       451.73     A
# 269584  96409250       8000         8000    7.99%       250.66     A
# 269585  96419201      13000        13000    5.32%       391.50     A
# 269586  96429334       6000         6000    7.49%       186.61     A
# 269587  96453160      15000        15000   19.99%       557.38     D
#
#        sub_grade                            emp_title  emp_length  \
# 0             E4                         Receptionist         0.5
# 1             A2                         Maintenance         10.0
# 2             D4                           hr manager         2.0
# 3             C3                   Sublet cordinator          2.0
# 4             C3                                  CIO         3.0
# ...          ...                                  ...         ...
# 269583        A1                    Emergency manager        10.0
# 269584        A5                             Techniti        10.0
# 269585        A1                     flight attendant        10.0
# 269586        A4  Empty Multi-level Distribution Supv         5.0
# 269587        D4                   Systems Specialist         0.5
#
#        home_ownership  annual_inc verification_status    issue_d  loan_status  \
# 0                RENT     30784.0        Not Verified 2016-08-01   Fully Paid
# 1            MORTGAGE     65000.0        Not Verified 2016-01-01  Charged Off
# 2                RENT     65000.0     Source Verified 2016-05-01  Charged Off
# 3                RENT     30000.0        Not Verified 2016-04-01   Fully Paid
# 4                RENT    180000.0            Verified 2016-03-01   Fully Paid
# ...               ...         ...                 ...        ...          ...
# 269583       MORTGAGE     98000.0     Source Verified 2016-12-01   Fully Paid
# 269584       MORTGAGE     57000.0     Source Verified 2016-12-01   Fully Paid
# 269585       MORTGAGE    101800.0        Not Verified 2016-12-01  Charged Off
# 269586           RENT     60000.0            Verified 2016-12-01   Fully Paid
# 269587           RENT     78200.0            Verified 2016-12-01   Fully Paid
#
#                    purpose                    title addr_state    dti  \
# 0       debt_consolidation       Debt consolidation         WA  16.96
# 1         home_improvement         Home improvement         NE  10.84
# 2       debt_consolidation       Debt consolidation         ME  18.24
# 3                    other                    Other         CA  13.02
# 4       debt_consolidation       Debt consolidation         VA  16.31
# ...                    ...                      ...        ...    ...
# 269583         credit_card  Credit card refinancing         PA   4.76
# 269584         credit_card  Credit card refinancing         KS  28.45
# 269585         credit_card  Credit card refinancing         IN  18.91
# 269586      small_business                 Business         GA  20.06
# 269587  debt_consolidation       Debt consolidation         NY  10.93
#
#         delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 0                 0         Apr-2003             665              669
# 1                 0         Mar-2002             705              709
# 2                 0         Sep-2002             660              664
# 3                 0         May-2006             710              714
# 4                 0         Mar-2001             665              669
# ...             ...              ...             ...              ...
# 269583            1         Feb-2003             705              709
# 269584            3         Oct-1996             680              684
# 269585            0         Jul-1997             720              724
# 269586            0         Mar-2003             705              709
# 269587            0         Oct-2003             675              679
#
#         inq_last_6mths  open_acc  pub_rec  revol_bal  revol_util  total_acc  \
# 0                  4.0        14        1       7849       0.740         36
# 1                  0.0         5        1       3012       0.354         11
# 2                  1.0        19        0      14741       0.819         26
# 3                  0.0         9        0       4557       0.260         12
# 4                  0.0         5        0      26143       1.005         39
# ...                ...       ...      ...        ...         ...        ...
# 269583             0.0        15        0       8012       0.105         31
# 269584             0.0         7        0       5938       0.367         34
# 269585             0.0         8        3      21213       0.575         21
# 269586             0.0         7        0      12442       0.396         22
# 269587             0.0         9        0      13846       0.796         26
#
#        initial_list_status   total_pymnt  recoveries last_pymnt_d  \
# 0                        w   4737.256142        0.00   2018-06-01
# 1                        w   5145.480000        0.00   2017-11-01
# 2                        w   7123.750000      507.72   2017-08-01
# 3                        w   7043.272508        0.00   2017-12-01
# 4                        f  41853.125632        0.00   2018-03-01
# ...                    ...           ...         ...          ...
# 269583                   w  15914.694801        0.00   2018-06-01
# 269584                   w   8342.110922        0.00   2017-08-01
# 269585                   w   5862.890000        0.00   2018-04-01
# 269586                   w   6640.163454        0.00   2019-02-01
# 269587                   f  19733.611970        0.00   2019-04-01
#
#         tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0                  0         8351          0.0          1.0          0.0
# 1                  0        74131          0.0          2.0          0.0
# 2                  0       173057          2.0         12.0          2.0
# 3                  0         8950          2.0          0.0          0.0
# 4                  0       222371          0.0          3.0          1.0
# ...              ...          ...          ...          ...          ...
# 269583           434       175233          2.0          1.0          0.0
# 269584             0       146207          0.0          3.0          0.0
# 269585             0       168092          0.0          2.0          0.0
# 269586             0        45718          0.0          2.0          1.0
# 269587             0       129058          0.0          5.0          0.0
#
#         open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0               0.0                50.0         502.0      8.0          4.0
# 1               1.0                15.0       17290.0     73.0          0.0
# 2               6.0                 6.0      158316.0    115.0          3.0
# 3               1.0                13.0        4393.0     92.0          4.0
# 4               1.0                 8.0      196228.0     92.0          0.0
# ...             ...                 ...           ...      ...          ...
# 269583          1.0                19.0        1680.0     14.0          3.0
# 269584          1.0                19.0       65964.0     30.0          1.0
# 269585          2.0                14.0       20845.0     40.0          2.0
# 269586          1.0                 8.0       33276.0     84.0          0.0
# 269587          2.0                17.0      115212.0    107.0          1.0
#
#         open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# 0              13.0      1158.0      74.0             10650     2.0
# 1               1.0      1569.0      63.0              8500     2.0
# 2               3.0      4878.0     110.0             18000     2.0
# 3               8.0      1502.0      40.0             17500     0.0
# 4               0.0         0.0      95.0             26000     0.0
# ...             ...         ...       ...               ...     ...
# 269583          6.0      3151.0      11.0             76300     0.0
# 269584          1.0      2480.0      32.0             16200     0.0
# 269585          3.0      2482.0      47.0             36900     1.0
# 269586          5.0      4910.0      64.0             31400     3.0
# 269587          1.0      6084.0      98.0             17400     0.0
#
#         total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 0               4.0           6.0                    13          596
# 1               0.0           1.0                     3        14826
# 2               2.0           4.0                     9         9108
# 3               0.0           0.0                     9          994
# 4               1.0           0.0                     1        55593
# ...             ...           ...                   ...          ...
# 269583          1.0           1.0                     7        12517
# 269584          2.0           1.0                     2        20887
# 269585          2.0           2.0                     5        21012
# 269586          0.0           4.0                     6         6531
# 269587          3.0           0.0                     3        14340
#
#         bc_open_to_buy  bc_util  mo_sin_old_il_acct  mo_sin_old_rev_tl_op  \
# 0                907.0     79.0               160.0                   127
# 1               5488.0     35.4               166.0                    35
# 2               2654.0     81.8               163.0                    48
# 3               8624.0     33.7               119.0                    63
# 4                  1.0      1.0               163.0                   180
# ...                ...      ...                 ...                   ...
# 269583         32812.0     12.5               137.0                   166
# 269584            20.0     99.2               242.0                   227
# 269585           718.0     77.6               142.0                   233
# 269586         14182.0     40.7               165.0                   138
# 269587            54.0     99.6               120.0                   158
#
#         mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 0                           7               7         0                   7.0
# 1                          16              12         3                  16.0
# 2                           6               6         0                   6.0
# 3                           5               5         0                   5.0
# 4                          55               8         0                   1.0
# ...                       ...             ...       ...                   ...
# 269583                      4               4         3                   4.0
# 269584                      9               9         3                   9.0
# 269585                     11              11         3                  11.0
# 269586                     15               8         1                  94.0
# 269587                     10              10         0                  10.0
#
#         mths_since_recent_inq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                         2.0                      1               7
# 1                         3.0                      0               2
# 2                         0.0                      1               4
# 3                        23.0                      0               5
# 4                         1.0                      1               0
# ...                       ...                    ...             ...
# 269583                   12.0                      0               2
# 269584                    9.0                      2               1
# 269585                   11.0                      0               1
# 269586                    9.0                      2               3
# 269587                   17.0                      0               3
#
#         num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0                    13           14         17         11             13
# 1                     2            2          2          5              2
# 2                     6            5          5         19              7
# 3                     6            6          6          2              8
# 4                     1            0          4         30              2
# ...                 ...          ...        ...        ...            ...
# 269583                5            5          9          4             12
# 269584                3            1         10         16              3
# 269585                4            1          4          7              5
# 269586                4            3          7          8              5
# 269587                3            3          4         13              4
#
#         num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_90g_dpd_24m  \
# 0                  25                   13        14                   0
# 1                   3                    2         5                   0
# 2                   7                    6        19                   0
# 3                  10                    6         9                   0
# 4                   9                    1         5                   0
# ...               ...                  ...       ...                 ...
# 269583             24                    5        15                   0
# 269584             15                    3         7                   1
# 269585             11                    4         8                   0
# 269586             13                    4         7                   0
# 269587             12                    3         9                   0
#
#         num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# 0                        4            69.0              85.7
# 1                        1           100.0               0.0
# 2                        5           100.0              60.0
# 3                        4           100.0              16.7
# 4                        1           100.0               1.0
# ...                    ...             ...               ...
# 269583                   3            93.5               0.0
# 269584                   1            76.5             100.0
# 269585                   2           100.0             100.0
# 269586                   1            90.9              33.3
# 269587                   1           100.0             100.0
#
#         pub_rec_bankruptcies  tot_hi_cred_lim  total_bal_ex_mort  \
# 0                          1            16579               8351
# 1                          1            87102              20302
# 2                          0           145285             173057
# 3                          0            22300               8950
# 4                          0           233798             222371
# ...                      ...              ...                ...
# 269583                     0           269003               9692
# 269584                     0           185355              71902
# 269585                     0           244965              42058
# 269586                     0            70949              45718
# 269587                     0           120048             129058
#
#         total_bc_limit  total_il_high_credit_limit  Qrtr  \
# 0                 6350                        5929     3
# 1                 8500                       23822     1
# 2                14600                      127285     2
# 3                13000                        4800     2
# 4                    0                      207798     1
# ...                ...                         ...   ...
# 269583           37500                       12489     4
# 269584            2500                       88422     4
# 269585            3200                       52184     4
# 269586           23900                       39549     4
# 269587           13900                      102648     4
#
#         loan_lifetime_in_months  estimated_monthly_paymnent  realised_return
# 0                     21.979917                  215.526567         0.121199
# 1                     22.012772                  233.749749        -0.125074
# 2                     15.014682                  474.452272        -0.053546
# 3                     20.008624                  352.011831         0.069806
# 4                     23.984065                 1745.038840         0.075256
# ...                         ...                         ...              ...
# 269583                17.971622                  885.545843         0.034924
# 269584                 7.983737                 1044.888014         0.031787
# 269585                15.967474                  367.177058        -0.221425
# 269586                26.021068                  255.184123         0.047272
# 269587                27.959506                  705.792574         0.108815
#
# [269558 rows x 83 columns]

# %%
all_year_19['earliest_cr_line']
# Out:
# 0         Apr-2003
# 1         Mar-2002
# 2         Sep-2002
# 3         May-2006
# 4         Mar-2001
#             ...
# 269583    Feb-2003
# 269584    Oct-1996
# 269585    Jul-1997
# 269586    Mar-2003
# 269587    Oct-2003
# Name: earliest_cr_line, Length: 269558, dtype: object

# %%
# catgoriel 
# application_type

#initial_list_status
all_year_19.initial_list_status.unique()
# looks bool - swich to 1,0
all_year_19.initial_list_status.replace(to_replace='f',value=0,inplace=True)
all_year_19.initial_list_status.replace(to_replace='w',value=0,inplace=True)

def years_between(date) :
    diff=(datetime.strptime("01/01/2016",'%d/%m/%Y')-datetime.strptime(date,'%d/%m/%Y')).days/365
    
    return np.round(diff,decimals=1)
    
# earliest_cr_line- make it years from.
#all_year_19.earliest_cr_line = all_year_19.earliest_cr_line.apply(convert_date)
#all_year_19.earliest_cr_line = all_year_19.earliest_cr_line.apply(years_between)
#we can make it east west and see if we got some corr 
# to realised return

east_west=[]

west_states = ['CA', 'TX', 'AZ', 'CO', 'WA', 'OR', 'NV', 'UT', 'NM', 'ID', 'MT', 'WY', 'HI', 'AK']

east_states = ['NY', 'FL', 'IL', 'NJ', 'OH', 'GA', 'PA', 'NC', 'MI', 'VA', 'MA', 'MD', 'MN', 'IN', 'TN', 'MO', 'CT', 'WI', 'SC', 'AL', 'LA', 'KY', 'OK', 'KS', 'AR', 'MS', 'NH', 'NE', 'RI', 'ME', 'DE', 'ND', 'DC', 'VT', 'SD', 'WV']

for i in all_year_19.addr_state :
    if i in west_states : 
        east_west.append("1")
    else : 
        east_west.append("0")
all_year_19.drop(columns="addr_state")
all_year_19["west1_east0"] = east_west

# %%
corr = all_year_19.corr()

# %%
corr.columns[corr['realised_return'].abs() < 0.01]
# Out:
# Index(['delinq_2yrs', 'revol_util', 'total_acc', 'tot_coll_amt', 'open_act_il',
#        'total_bal_il', 'total_cu_tl', 'bc_util', 'num_accts_ever_120_pd',
#        'num_bc_tl', 'num_il_tl', 'num_rev_accts', 'num_tl_90g_dpd_24m',
#        'pct_tl_nvr_dlq', 'percent_bc_gt_75'],
#       dtype='object')

# %%
corr.realised_return[corr.realised_return.abs() < 0.1]
# Out:
# id                           -0.076344
# loan_amnt                    -0.014439
# funded_amnt                  -0.014441
# installment                  -0.027604
# emp_length                    0.034445
# annual_inc                    0.019041
# dti                          -0.035572
# delinq_2yrs                  -0.007526
# fico_range_low                0.047003
# fico_range_high               0.047003
# inq_last_6mths               -0.057291
# open_acc                     -0.012375
# pub_rec                      -0.014928
# revol_bal                     0.019170
# revol_util                    0.001662
# total_acc                    -0.001706
# tot_coll_amt                  0.001921
# tot_cur_bal                   0.040906
# open_acc_6m                  -0.051286
# open_act_il                  -0.002936
# open_il_12m                  -0.054103
# open_il_24m                  -0.053805
# mths_since_rcnt_il            0.034840
# total_bal_il                  0.002269
# il_util                      -0.039421
# open_rv_12m                  -0.042824
# open_rv_24m                  -0.060652
# max_bal_bc                    0.030594
# all_util                     -0.021979
# total_rev_hi_lim              0.024732
# inq_fi                       -0.047560
# total_cu_tl                  -0.006948
# inq_last_12m                 -0.053722
# acc_open_past_24mths         -0.073488
# avg_cur_bal                   0.043776
# bc_open_to_buy                0.022428
# bc_util                      -0.000483
# mo_sin_old_il_acct            0.020715
# mo_sin_old_rev_tl_op          0.025583
# mo_sin_rcnt_rev_tl_op         0.034865
# mo_sin_rcnt_tl                0.036147
# mort_acc                      0.044529
# mths_since_recent_bc          0.035007
# mths_since_recent_inq         0.044331
# num_accts_ever_120_pd         0.001978
# num_actv_bc_tl               -0.015125
# num_actv_rev_tl              -0.021271
# num_bc_sats                  -0.015840
# num_bc_tl                    -0.006978
# num_il_tl                    -0.005602
# num_op_rev_tl                -0.019017
# num_rev_accts                -0.007645
# num_rev_tl_bal_gt_0          -0.019425
# num_sats                     -0.012127
# num_tl_90g_dpd_24m           -0.004083
# num_tl_op_past_12m           -0.060590
# pct_tl_nvr_dlq               -0.008624
# percent_bc_gt_75             -0.006802
# pub_rec_bankruptcies         -0.020917
# tot_hi_cred_lim               0.043169
# total_bal_ex_mort             0.011367
# total_bc_limit                0.029148
# total_il_high_credit_limit    0.010243
# Qrtr                         -0.078180
# estimated_monthly_paymnent    0.029395
# Name: realised_return, dtype: float64

# %%
all_year_19['bc_util'].isna().sum()
# Out:
# 3239

# %%
TO_DUMIFY.append('title')

# %%
'''check column dti
In this case NAs make a small contribution to the data, we will simply replace it with the median value'''
distribution_dictionary['dti']
# Out:
#     Value  Count  Return on Investment Average  Percentage
# 0    18.0    204                      0.012259    0.075679
# 1    19.2    200                      0.011767    0.074196
# 2    12.0    196                      0.017120    0.072712
# 3    16.8    195                      0.012440    0.072341
# 4    10.8    182                      0.025396    0.067518
# 5    13.2    179                      0.029319    0.066405
# 6    15.6    175                      0.025035    0.064921
# 7    14.4    174                      0.012903    0.064550
# 8    20.4    172                      0.011806    0.063808
# 9    21.6    166                      0.008322    0.061582
# 10   22.8    163                      0.014200    0.060469
# 11  18.48    163                      0.030313    0.060469
# 12    9.6    162                      0.024623    0.060098
# 13  16.32    160                      0.013950    0.059356
# 14  14.88    159                      0.013508    0.058985
# 15  19.92    156                      0.001067    0.057873
# 16  18.72    156                      0.000913    0.057873
# 17  15.36    155                      0.021106    0.057502
# 18  17.28    154                      0.007770    0.057131
# 19  13.92    153                      0.031745    0.056760
# 20  12.96    152                      0.020504    0.056389
# 21  14.64    152                      0.012193    0.056389
# 22  16.56    149                      0.000892    0.055276
# 23   15.4    148                      0.031836    0.054905
# 24  13.44    145                      0.025032    0.053792
# 25   16.4    145                      0.023319    0.053792
# 26  14.25    145                      0.028744    0.053792
# 27   15.0    144                      0.022846    0.053421
# 28   16.2    144                      0.028481    0.053421
# 29  18.34    144                     -0.002014    0.053421
# 30     na     35                      0.016771    0.012984

# %%
print("the median is: ", np.median(all_year_19['dti'].dropna()))
value_to_replace_dti_nas = np.median(all_year_19['dti'].dropna())
all_year_19 = fill_nas_with(all_year_19, 'dti', value_to_replace_dti_nas)

# %%
all_year_19['dti'].describe()

# %%
sns.boxplot(data=all_year_19, y='dti')
plt.xlabel('Column Name')
plt.ylabel('Values')
plt.title('Box Plot of Column')
plt.show()

# %%
'''Shai:
summery of looking into na's: 

column = 'il_util'
# we will replace the na with the median value bc it is normally dist. 

col = 'total_bal_il' 

# we will replace the na with the median 

# col - revol_util
# for this col we will take the median

cols we think might have D.L: 
# col - mths_since_rcnt_il  
# col - open_il_24m
# col - open_il_12m
# col - open_act_il
# col - open_acc_6m'''

# %%
POTENTIAL_DATA_LEAKAG += ['mths_since_rcnt_il','open_il_24m','open_il_12m','open_act_il','open_acc_6m']

# %%
POTENTIAL_DATA_LEAKAG.append('mths_since_last_delinq')
POTENTIAL_DATA_LEAKAG.append('mths_since_last_record')

# %%
# col - total_bal_il
distribution_dictionary['total_bal_il']

# %%
# plot the histogram
plt.hist(all_year_19['total_bal_il'] , bins=20)
plt.xlabel('total_bal_il')
plt.ylabel('Frequency')
plt.title('Distribution of total_bal_il')
plt.show()

# %%
np.mean(all_year_19['total_bal_il'])

# %%
all_year_19 = fill_nas_with(all_year_19, 'total_bal_il', np.mean(all_year_19['total_bal_il']))

# %%
# for column il_util
distribution_dictionary['il_util']

# %%
Mean_il_util = np.mean(distribution_dictionary['il_util']['Return on Investment Average'])

# %%
plt.hist(all_year_19['il_util'] , bins=20)
plt.xlabel('total_bal_il')
plt.ylabel('Frequency')
plt.title('Distribution of total_bal_il')
plt.show()

# %%
all_year_19 = fill_nas_with(all_year_19, 'il_util', Mean_il_util)                                


mean_realised_return = np.mean(all_year_19['realised_return'])

# %%
# column check "percent_bc_gt_75"

# Percentage of all bankcard accounts > 75% of limit.sns.distplot(all_year_19["mo_sin_old_il_acct"])

sns.displot(all_year_19["percent_bc_gt_75"])

print("total na's :",sum(all_year_19["percent_bc_gt_75"].isna()))
print("delta of na rlsd rtrn :",all_year_19.realised_return[all_year_19["percent_bc_gt_75"].isna() ].mean()-mean_realised_return )

# with a low diffrande in mean and an understanding an NA represent the abesence of information we can fill with 0

fixed_value = 0 # most frequent value

all_year_19["percent_bc_gt_75"] =  all_year_19["percent_bc_gt_75"].fillna(fixed_value)

# %%
# column check "bc_open_to_buy"
# Total open to buy on revolving bankcards

sns.distplot(all_year_19["bc_open_to_buy"])
print('Distribution Plot of bc_open_to_buy')
print("total na's :",sum(all_year_19["bc_open_to_buy"].isna()))
print("delta of na rlsd rtrn :",all_year_19.realised_return[all_year_19["bc_open_to_buy"].isna() ].mean()-mean_realised_return )

# with a low diffrande in mean and an understanding an NA represent the abesence of information we can fill with 0

fixed_value = 0 # most frequent value
all_year_19["bc_open_to_buy"] =  all_year_19["bc_open_to_buy"].fillna(fixed_value)

# %%
# column check "all_util"
# Description: Balance to credit limit on all trades

ax = sns.distplot(all_year_19["all_util"])

print('Distribution Plot of all_util')
print("total na's :",sum(all_year_19["all_util"].isna()))
print("delta of na rlsd rtrn :",all_year_19.realised_return[all_year_19["all_util"].isna() ].mean()-mean_realised_return )

# with a low count and a low and simmiler mean there will be no affect on disterbution
fixed_value = all_year_19["all_util"].mean() #mean of normal disterbution

# filling na
all_year_19["all_util"] =  all_year_19["all_util"].fillna(fixed_value)

# %%
# column check "total_cu_tl"
# Number of finance trades

print(all_year_19["total_cu_tl"].value_counts().head())
sns.boxplot(all_year_19["total_cu_tl"])

print("total na's :",sum(all_year_19["total_cu_tl"].isna()))
print("delta of na rlsd rtrn :",all_year_19.realised_return[all_year_19["total_cu_tl"].isna() ].mean()-mean_realised_return )

# with a low count and a low and simmiler mean there will be no affect on disterbution

fixed_value = 0 # most frequent value
all_year_19["total_cu_tl"] =  all_year_19["total_cu_tl"].fillna(fixed_value)

# %% [markdown]
# ## Features with potential data leakage for further Check with Soft-Lending:

# %%
features_with_potential_dl_hands_on_analysis = ['il_util','delinq_2yrs','collections_12_mths_ex_med','chargeoff_within_12_mths',
'avg_cur_bal','acc_now_delinq','acc_open_past_24mths','mths_since_rcnt_il','open_il_24m','open_il_12m',
'inq_last_6mths','open_act_il', 'open_acc_6m','mo_sin_old_rev_tl_op',
 'mo_sin_rcnt_rev_tl_op','mths_since_last_major_derog','tot_cur_bal',
 'mo_sin_rcnt_tl','num_accts_ever_120_pd','num_actv_bc_tl','total_acc',
 'num_actv_rev_tl','num_tl_90g_dpd_24m','total_bal_il','num_tl_op_past_12m',
'mths_since_last_delinq','mths_since_last_record', 'open_rv_12m', 'open_rv_24m', 'inq_last_12m',
'mo_sin_old_il_acct', 'mths_since_recent_bc','mths_since_recent_bc_dlq', 'mths_since_recent_inq', 
'mths_since_recent_revol_delinq', 'num_tl_120dpd_2m', 'max_bal_bc', 'inq_fi', 'bc_util']

# %%
list(features_with_potential_dl_hands_on_analysis)
# Out:
# ['il_util',
#  'delinq_2yrs',
#  'collections_12_mths_ex_med',
#  'chargeoff_within_12_mths',
#  'avg_cur_bal',
#  'acc_now_delinq',
#  'acc_open_past_24mths',
#  'mths_since_rcnt_il',
#  'open_il_24m',
#  'open_il_12m',
#  'inq_last_6mths',
#  'open_act_il',
#  'open_acc_6m',
#  'mo_sin_old_rev_tl_op',
#  'mo_sin_rcnt_rev_tl_op',
#  'mths_since_last_major_derog',
#  'tot_cur_bal',
#  'mo_sin_rcnt_tl',
#  'num_accts_ever_120_pd',
#  'num_actv_bc_tl',
#  'total_acc',
#  'num_actv_rev_tl',
#  'num_tl_90g_dpd_24m',
#  'total_bal_il',
#  'num_tl_op_past_12m',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_rv_12m',
#  'open_rv_24m',
#  'inq_last_12m',
#  'mo_sin_old_il_acct',
#  'mths_since_recent_bc',
#  'mths_since_recent_bc_dlq',
#  'mths_since_recent_inq',
#  'mths_since_recent_revol_delinq',
#  'num_tl_120dpd_2m',
#  'max_bal_bc',
#  'inq_fi',
#  'bc_util']

# %%
POTENTIAL_DATA_LEAKAG += features_with_potential_dl_hands_on_analysis

# %%
POTENTIAL_DATA_LEAKAG

# %% [markdown]
# # Feature Unification

# %% [markdown]
# In this stage we will look at features that retain the same information. thus we can drop them, or unify them. We will do this by checking their correlation, if their correlation is identical we can drop them

# %%
len(all_year_19.columns)

# %%
COL_TO_DROP_DUPLICATION = []

# %%
correlation_matrix = all_year_19.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')

# Display the heatmap
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
COL_TO_DROP_DUPLICATION += ['installment','funded_amnt','fico_range_low'],

# %%
all_year_19.dtypes

# %%
all_year_19.columns

# %%
# columns with since/past/current
# open_rv_12m
# open_rv_24m
# inq_last_12m
# mo_sin_old_il_acct
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_tl_120dpd_2m
# max_bal_bc
# inq_fi
# bc_util

# %% [markdown]
# # Snapshot for concluding all Varriables and columns. stage1. MAY 01, 2023

# %%
POTENTIAL_DATA_LEAKAG += [
   'open_rv_12m', 'open_rv_24m', 'inq_last_12m','mo_sin_old_il_acct',
    'mths_since_recent_bc','mths_since_recent_bc_dlq','mths_since_recent_inq',
    'mths_since_recent_revol_delinq','num_tl_120dpd_2m','max_bal_bc','inq_fi','bc_util'
]

# %%
UNIQUE_COLUMNS

# %%
IRRELEVANT_COLUMNS

# %%
print(f"Category 1 columns: Filtered Out: {len(DF_FILTERED_OUT_COLUMNS.columns)}, N/A's, irrelevant, and clear Dataleakage")

# %%
COLUMNS_REMOVED_BECAUSE_OF_NA

# %%
len(IRRELEVANT_COLUMNS)

# %%
DATA_LEAKAGE_COLUMNS

# %%
DF_FILTERED_OUT_COLUMNS.columns

# %%
print(f"Category 2 columns: Potential Leakage: {len(POTENTIAL_DATA_LEAKAG)}")

# %%
POTENTIAL_DATA_LEAKAG = list(set(POTENTIAL_DATA_LEAKAG))

# %%
88 - len(POTENTIAL_DATA_LEAKAG)

# %%
len(feature_columns_v1)

# %%
len(Q1_18.columns)

# %% [markdown]
# # Work in progress bellow

# %%
grade_groups_year_19.std().year_realised_return

# %%
grade_groups_year_19 = all_year_19.groupby(["grade","sub_grade"])
grade_groups_year_19.mean().year_realised_return

# %%
grade_groups_year_19 = all_year_19.groupby(["grade","sub_grade"])
grade_groups_year_19.std().year_realised_return

# %%
# cheack 1 - lets make a worst case senario in which the payment is fully paid on the last month
worst_rlsd_rate = []
shpizer_payments_2 = []

for _, row in all_year_19.iterrows():
    pymnts = [row['funded_amnt']*-1]  
    pymnts += [0] * (int(row['months'])-1) 
    pymnts += [row['total_pymnt']]
    shpizer_payments_2.append(pymnts)

# %%
# here are the worst possible payments according to dates
shpizer_payments_2[0]

# %%
# now agian using irr
# Monthly rate to yearly rate
worst_realised_rate = []
for i in shpizer_payments_2 :
    # Monthly rate to yearly rate
    worst_realised_rate.append(((npf.irr(i)+1)**12)-1)

# %%
all_year_19["worst_realised_rate"] = worst_realised_rate

# %%
all_year_19.worst_realised_rate.describe()

# %%
grade_groups_year_19 = all_year_19.groupby(["grade","sub_grade"])
grade_groups_year_19.mean().worst_realised_rate

# %%
## now lets see what makes some loans have over 100% realised int rate
check1 = all_year_19[["funded_amnt","total_pymnt","months","monthly_paymnent","year_realised_return","int_rate","worst_realised_rate"]][all_year_19.year_realised_return >= 1]

# %%
# check1.year_realised_return.describe()
check1.year_realised_return.sort_values(ascending=False)

# %%
# only 8 loans 
check1

# %%
# thats wired... lets have a closer look 
((npf.irr([-20000,5881,5881,5881,5881])+1)**12)-1
((npf.irr([-2000,2166])+1)**12)-1
# ok, lets check how they have low months
check2 = all_year_19[["issue_d","last_pymnt_d","months","funded_amnt","total_pymnt","year_realised_return"]][all_year_19.year_realised_return >= 1]

# %%
check2
# they acually look valid... :( 
# we can again think of if irr asumption (reinvesting) is the best fit for us....
# maybe if we set an YTM% of 2% as the reinvesment rate in the IRR ?..?..?..?..?

# %%
# Assuming reinvestment at a specific rate (2% yearly)
reinvestment_rate = 0.02

# Monthly rate!
realized_rate = []
for i in shpizer_payments:
    realized_rate.append(npf.mirr(i, reinvestment_rate, reinvestment_rate/12))

# Calculate realized rates with specified reinvestment rate
yearly_realized_rates = ((np.array(realized_rate) + 1) ** 12) - 1

# %%
len(all_year_19.columns),len(all_year_18.columns)

# %%
columns_19 = list(all_year_19.columns)

# %%
# these are all the 18 features that are not included in 19
exclude_18 = all_year_18.columns[all_year_18.columns.isin(all_year_19)== False ]
exclude_18

# %%
# these are all the 19 features that are not included in 18
exclude_19 = all_year_19.columns[all_year_19.columns.isin(all_year_18)== False ]
exclude_19

# %%
# we want to check for perminant data - all of this are not ! 
all_year_19_copy = all_year_19.drop(columns=exclude_19)
all_year_18_copy = all_year_18.drop(columns=exclude_18)

# %%
# test
